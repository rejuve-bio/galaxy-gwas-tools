# %%
import sys
sys.path.insert(0,"/home/yunye/work/gwaslab/src")
import gwaslab as gl
import pandas as pd

# %% [markdown]
# ### loading

# %%
gl.check_downloaded_ref()
# Out:
# 2026/01/10 13:31:45 Start to check downloaded reference files...
# 2026/01/10 13:31:45  -Checking the config file:/mnt/hdd_1/ofgeha/galaxy-gwas-tools/.venv/lib/python3.12/site-packages/gwaslab/data/config.json
# 2026/01/10 13:31:45  -Config file exists.
# 2026/01/10 13:31:45  -Updating config.json...
# 2026/01/10 13:31:45  - Local file keywords:  1kg_dbsnp151_hg38_auto
# {'1kg_dbsnp151_hg38_auto': {'local_path': '/home/ofgeha/.gwaslab/1kg_dbsnp151_hg38_auto.txt.gz',
#   'description': '1KG dbSNP151 hg38 auto variants table containing SNP ID, chromosome, position, effect allele, non-effect allele, and rsID mappings for autosomal variants.',
#   'suggested_use': 'SNP annotation and rsID mapping'}}

# %%
mysumstats = gl.Sumstats(
    "/mnt/hdd_1/ofgeha/galaxy-gwas-tools/Data/21001_T2T_liftover_rsid.tsv.gz",
    snpid="SNPID",
    chrom="CHR",
    pos="POS",
    ea="EA",            
    nea="NEA",          
    eaf="EAF",          
    beta="BETA",
    se="SE",
    p="P",
    # Note: 'Dir' and 'N' are not in your column list, 
    # so we should omit them or point to the correct ones.
    # n="n_complete_samples", # Optional: if you want to use sample size
    verbose=True,
    readargs={'sep': '\t'}
)
# Out:
# 2026/01/10 12:17:58 GWASLab v4.0.4 https://cloufield.github.io/gwaslab/
# 2026/01/10 12:17:58 (C) 2022-2026, Yunye He, Kamatani Lab, GPL-3.0 license, gwaslab@gmail.com
# 2026/01/10 12:17:58 Python version: 3.12.3 (main, Nov  6 2025, 13:44:16) [GCC 13.3.0]
# 2026/01/10 12:17:58 Start to initialize gl.Sumstats from file :/mnt/hdd_1/ofgeha/galaxy-gwas-tools/Data/21001_T2T_liftover_rsid.tsv.gz
# 2026/01/10 12:18:22  -Reading columns          : BETA,SNPID,SE,NEA,EA,P,CHR,EAF,POS
# 2026/01/10 12:18:22  -Renaming columns to      : BETA,SNPID,SE,NEA,EA,P,CHR,EAF,POS
# 2026/01/10 12:18:22  -Current Dataframe shape : 13640038  x  9
# 2026/01/10 12:18:23  -Initiating a status column: STATUS ...
# 2026/01/10 12:18:23 #WARNING! Version of genomic coordinates is unknown for homo sapiens (build: 99)...
# 2026/01/10 12:18:26 Start to reorder the columns ...(v4.0.4)
# 2026/01/10 12:18:26  -Reordering columns to    : SNPID,CHR,POS,EA,NEA,STATUS,EAF,BETA,SE,P
# ...

# %%
# Wildcard path for your hg38 VCFs
ref_pattern = "/mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser/gwas-ref/homo_sapiens-chr%CHR.vcf.gz"

mysumstats.harmonize(
    ref_infer=ref_pattern,    # Path to your VCF reference
    ref_alt_freq="AF",        # Field in VCF for freq comparison
    basic_check=False,        # Skipping as you already ran it
    threads=4                 # Parallel processing
)
# Out:
# 2026/01/10 12:19:08 Start to infer strand for palindromic SNPs/align indistinguishable indels ...(v4.0.4)
# 2026/01/10 12:19:08  -Number of threads/cores to use: 4
# 2026/01/10 12:19:08  -Current Dataframe shape : 13640038 x 10 ; Memory usage: 953.30 MB
# 2026/01/10 12:19:08 #WARNING! Reference file not found: /mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser/gwas-ref/homo_sapiens-chr%CHR.vcf.gz. Using default format.
# 2026/01/10 12:19:08  -Field for alternative allele frequency in VCF INFO: AF
# 2026/01/10 12:19:09  -Identified  0  palindromic SNPs...
# 2026/01/10 12:19:09  -After filtering by MAF<= 0.4 , 0 palindromic SNPs with unknown strand will be inferred...
# 2026/01/10 12:19:09 #WARNING! No palindromic variants available for checking.
# 2026/01/10 12:19:11   -Non-palindromic :  0
# 2026/01/10 12:19:12   -Palindromic SNPs on + strand:  0
# 2026/01/10 12:19:13   -Palindromic SNPs on - strand and needed to be flipped: 0
# ...
