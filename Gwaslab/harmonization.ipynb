# %%
# Examples:
chroms = [22]                    # quick test
# chroms = list(range(1, 23))      # autosomes
# chroms = list(range(1, 24))      # 1–23
# chroms = None                    # FULL genome

# chroms = None   # <-- global run

# %%
import gzip

def filter_gwas_by_chrom(
    input_gwas,
    output_gwas,
    chroms=None,
    chrom_col=0
):
    """
    chroms: list[int] or None
    chrom_col: 0-based column index of chromosome
    """

    if chroms is None:
        # No filtering → copy file as-is
        with gzip.open(input_gwas, "rb") as fin, gzip.open(output_gwas, "wb") as fout:
            fout.write(fin.read())
        return "unfiltered"

    chroms = set(str(c) for c in chroms)

    with gzip.open(input_gwas, "rt") as fin, gzip.open(output_gwas, "wt") as fout:
        header = fin.readline()
        fout.write(header)

        for line in fin:
            if line.split("\t")[chrom_col] in chroms:
                fout.write(line)

    return f"filtered_chr_{'_'.join(sorted(chroms))}"

# %%
input_gwas = "/mnt/hdd_1/ofgeha/test/21001_raw.gwas.imputed_v3.both_sexes.tsv.gz"

if chroms is None:
    gwas_for_nf = input_gwas
    mode = "global"
else:
    gwas_for_nf = "/mnt/hdd_1/ofgeha/test/21001_raw_subset.tsv.gz"
    mode = filter_gwas_by_chrom(
        input_gwas,
        gwas_for_nf,
        chroms=chroms
    )

print("Run mode:", mode)
print("GWAS used:", gwas_for_nf)
# Out:
# Run mode: filtered_chr_22
# GWAS used: /mnt/hdd_1/ofgeha/test/21001_raw_subset.tsv.gz

# %%
import subprocess

cmd = [
    "nextflow", "run", "EBISPOT/gwas-sumstats-harmoniser",
    "-r", "v1.1.10",
    "--ref", "/mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser/gwas-ref",
    "--harm",
    "--file", gwas_for_nf,
    "-profile", "standard,singularity",
    "-resume"
]

print(" ".join(cmd))
subprocess.run(cmd, check=True)
# Out:
# nextflow run EBISPOT/gwas-sumstats-harmoniser -r v1.1.10 --ref /mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser/gwas-ref --harm --file /mnt/hdd_1/ofgeha/test/21001_raw_subset.tsv.gz -profile standard,singularity -resume
# Nextflow 25.10.3 is available - Please consider updating your version to it
#  N E X T F L O W   ~  version 25.10.0
#
# Launching `https://github.com/EBISPOT/gwas-sumstats-harmoniser` [agitated_brenner] DSL2 - revision: 436c17a91c [v1.1.10]
#
# Start harmonising files
# Harmonizing the file /mnt/hdd_1/ofgeha/test/21001_raw_subset.tsv.gz
# [-        ] NFC…jor_direction:map_to_build -
# [-        ] NFC…rection:ten_percent_counts -
# [-        ] NFC…ion:ten_percent_counts_sum -
# [-        ] NFC…ion:generate_strand_counts -
#
# [-        ] NFC…jor_direction:map_to_build -
# [-        ] NFC…rection:ten_percent_counts -
# [-        ] NFC…ion:ten_percent_counts_sum -
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [-        ] NFC…RM:main_harm:harmonization -
# [-        ] NFC…arm:concatenate_chr_splits -
# [-        ] NFC…LOGHARM:quality_control:qc -
# [-        ] NFC…_control:harmonization_log -
# [-        ] NFC…y_control:update_meta_yaml -
# no,other setting
# [chr1, chr12, chr15, chr13, chr19, chr18, chrY, chr14, chr7, chr16, chr3, chr8, chrX, chr5, chrMT, chr21, chr9, chr22, chr10, chr20, chr17, chr2, chr6, chr11, chr4,  is being harmonized]
#
# executor >  local (1)
# [8e/be45ca] NFC…o_build (21001_raw_subset) | 0 of 1
# [-        ] NFC…rection:ten_percent_counts -
# [-        ] NFC…ion:ten_percent_counts_sum -
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [-        ] NFC…RM:main_harm:harmonization -
# [-        ] NFC…arm:concatenate_chr_splits -
# [-        ] NFC…LOGHARM:quality_control:qc -
# [-        ] NFC…_control:harmonization_log -
# [-        ] NFC…y_control:update_meta_yaml -
# no,other setting
# [chr1, chr12, chr15, chr13, chr19, chr18, chrY, chr14, chr7, chr16, chr3, chr8, chrX, chr5, chrMT, chr21, chr9, chr22, chr10, chr20, chr17, chr2, chr6, chr11, chr4,  is being harmonized]
#
# executor >  local (9)
# [8e/be45ca] NFC…o_build (21001_raw_subset) | 1 of 1 ✔
# [02/ff4799] NFC…s (21001_raw_subset_chr15) | 0 of 18
# [-        ] NFC…ion:ten_percent_counts_sum -
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [-        ] NFC…RM:main_harm:harmonization -
# [-        ] NFC…arm:concatenate_chr_splits -
# [-        ] NFC…LOGHARM:quality_control:qc -
# [-        ] NFC…_control:harmonization_log -
# [-        ] NFC…y_control:update_meta_yaml -
# no,other setting
# [chr1, chr12, chr15, chr13, chr19, chr18, chrY, chr14, chr7, chr16, chr3, chr8, chrX, chr5, chrMT, chr21, chr9, chr22, chr10, chr20, chr17, chr2, chr6, chr11, chr4,  is being harmonized]
#
# executor >  local (23)
# [8e/be45ca] NFC…o_build (21001_raw_subset) | 1 of 1 ✔
# [70/31df3a] NFC…ts (21001_raw_subset_chr3) | 0 of 25
# [-        ] NFC…ion:ten_percent_counts_sum -
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [-        ] NFC…RM:main_harm:harmonization -
# [-        ] NFC…arm:concatenate_chr_splits -
# [-        ] NFC…LOGHARM:quality_control:qc -
# [-        ] NFC…_control:harmonization_log -
# [-        ] NFC…y_control:update_meta_yaml -
# no,other setting
# [chr1, chr12, chr15, chr13, chr19, chr18, chrY, chr14, chr7, chr16, chr3, chr8, chrX, chr5, chrMT, chr21, chr9, chr22, chr10, chr20, chr17, chr2, chr6, chr11, chr4,  is being harmonized]
#
# executor >  local (26)
# [8e/be45ca] NFC…o_build (21001_raw_subset) | 1 of 1 ✔
# [09/bf4877] NFC…s (21001_raw_subset_chr16) | 0 of 25
# [-        ] NFC…ion:ten_percent_counts_sum -
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [-        ] NFC…RM:main_harm:harmonization -
# [-        ] NFC…arm:concatenate_chr_splits -
# [-        ] NFC…LOGHARM:quality_control:qc -
# [-        ] NFC…_control:harmonization_log -
# [-        ] NFC…y_control:update_meta_yaml -
# no,other setting
# [chr1, chr12, chr15, chr13, chr19, chr18, chrY, chr14, chr7, chr16, chr3, chr8, chrX, chr5, chrMT, chr21, chr9, chr22, chr10, chr20, chr17, chr2, chr6, chr11, chr4,  is being harmonized]
#
# executor >  local (26)
# [8e/be45ca] NFC…o_build (21001_raw_subset) | 1 of 1 ✔
# [68/0c5224] NFC…ts (21001_raw_subset_chrX) | 3 of 25
# [-        ] NFC…ion:ten_percent_counts_sum -
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [-        ] NFC…RM:main_harm:harmonization -
# [-        ] NFC…arm:concatenate_chr_splits -
# [-        ] NFC…LOGHARM:quality_control:qc -
# [-        ] NFC…_control:harmonization_log -
# [-        ] NFC…y_control:update_meta_yaml -
# no,other setting
# [chr1, chr12, chr15, chr13, chr19, chr18, chrY, chr14, chr7, chr16, chr3, chr8, chrX, chr5, chrMT, chr21, chr9, chr22, chr10, chr20, chr17, chr2, chr6, chr11, chr4,  is being harmonized]
#
# executor >  local (26)
# [8e/be45ca] NFC…o_build (21001_raw_subset) | 1 of 1 ✔
# [87/d2b874] NFC…s (21001_raw_subset_chr19) | 7 of 25
# [-        ] NFC…ion:ten_percent_counts_sum -
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [-        ] NFC…RM:main_harm:harmonization -
# [-        ] NFC…arm:concatenate_chr_splits -
# [-        ] NFC…LOGHARM:quality_control:qc -
# [-        ] NFC…_control:harmonization_log -
# [-        ] NFC…y_control:update_meta_yaml -
# no,other setting
# [chr1, chr12, chr15, chr13, chr19, chr18, chrY, chr14, chr7, chr16, chr3, chr8, chrX, chr5, chrMT, chr21, chr9, chr22, chr10, chr20, chr17, chr2, chr6, chr11, chr4,  is being harmonized]
#
# executor >  local (26)
# [8e/be45ca] NFC…o_build (21001_raw_subset) | 1 of 1 ✔
# [66/d600d1] NFC…s (21001_raw_subset_chr10) | 14 of 25
# [-        ] NFC…ion:ten_percent_counts_sum -
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [-        ] NFC…RM:main_harm:harmonization -
# [-        ] NFC…arm:concatenate_chr_splits -
# [-        ] NFC…LOGHARM:quality_control:qc -
# [-        ] NFC…_control:harmonization_log -
# [-        ] NFC…y_control:update_meta_yaml -
# no,other setting
# [chr1, chr12, chr15, chr13, chr19, chr18, chrY, chr14, chr7, chr16, chr3, chr8, chrX, chr5, chrMT, chr21, chr9, chr22, chr10, chr20, chr17, chr2, chr6, chr11, chr4,  is being harmonized]
#
# executor >  local (26)
# [8e/be45ca] NFC…o_build (21001_raw_subset) | 1 of 1 ✔
# [d0/6df0aa] NFC…ts (21001_raw_subset_chr9) | 23 of 25
# [-        ] NFC…ion:ten_percent_counts_sum -
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [-        ] NFC…RM:main_harm:harmonization -
# [-        ] NFC…arm:concatenate_chr_splits -
# [-        ] NFC…LOGHARM:quality_control:qc -
# [-        ] NFC…_control:harmonization_log -
# [-        ] NFC…y_control:update_meta_yaml -
# no,other setting
# [chr1, chr12, chr15, chr13, chr19, chr18, chrY, chr14, chr7, chr16, chr3, chr8, chrX, chr5, chrMT, chr21, chr9, chr22, chr10, chr20, chr17, chr2, chr6, chr11, chr4,  is being harmonized]
#
# executor >  local (26)
# [8e/be45ca] NFC…o_build (21001_raw_subset) | 1 of 1 ✔
# [09/bf4877] NFC…s (21001_raw_subset_chr16) | 24 of 25
# [-        ] NFC…ion:ten_percent_counts_sum -
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [-        ] NFC…RM:main_harm:harmonization -
# [-        ] NFC…arm:concatenate_chr_splits -
# [-        ] NFC…LOGHARM:quality_control:qc -
# [-        ] NFC…_control:harmonization_log -
# [-        ] NFC…y_control:update_meta_yaml -
# no,other setting
# [chr1, chr12, chr15, chr13, chr19, chr18, chrY, chr14, chr7, chr16, chr3, chr8, chrX, chr5, chrMT, chr21, chr9, chr22, chr10, chr20, chr17, chr2, chr6, chr11, chr4,  is being harmonized]
#
# executor >  local (27)
# [8e/be45ca] NFC…o_build (21001_raw_subset) | 1 of 1 ✔
# [ed/212e22] NFC…s (21001_raw_subset_chr22) | 25 of 25 ✔
# [f9/a85c3e] NFC…nts_sum (21001_raw_subset) | 0 of 1
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [-        ] NFC…RM:main_harm:harmonization -
# [-        ] NFC…arm:concatenate_chr_splits -
# [-        ] NFC…LOGHARM:quality_control:qc -
# [-        ] NFC…_control:harmonization_log -
# [-        ] NFC…y_control:update_meta_yaml -
# no,other setting
# [chr1, chr12, chr15, chr13, chr19, chr18, chrY, chr14, chr7, chr16, chr3, chr8, chrX, chr5, chrMT, chr21, chr9, chr22, chr10, chr20, chr17, chr2, chr6, chr11, chr4,  is being harmonized]
#
# executor >  local (27)
# [8e/be45ca] NFC…o_build (21001_raw_subset) | 1 of 1 ✔
# [ed/212e22] NFC…s (21001_raw_subset_chr22) | 25 of 25 ✔
# [f9/a85c3e] NFC…nts_sum (21001_raw_subset) | 0 of 1
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [-        ] NFC…RM:main_harm:harmonization -
# [-        ] NFC…arm:concatenate_chr_splits -
# [-        ] NFC…LOGHARM:quality_control:qc -
# [-        ] NFC…_control:harmonization_log -
# [-        ] NFC…y_control:update_meta_yaml -
# no,other setting
# [chr1, chr12, chr15, chr13, chr19, chr18, chrY, chr14, chr7, chr16, chr3, chr8, chrX, chr5, chrMT, chr21, chr9, chr22, chr10, chr20, chr17, chr2, chr6, chr11, chr4,  is being harmonized]
#
# executor >  local (30)
# [8e/be45ca] NFC…o_build (21001_raw_subset) | 1 of 1 ✔
# [ed/212e22] NFC…s (21001_raw_subset_chr22) | 25 of 25 ✔
# [f9/a85c3e] NFC…nts_sum (21001_raw_subset) | 1 of 1 ✔
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [3c/b0ca38] NFC…n (21001_raw_subset_chr19) | 0 of 7
# [-        ] NFC…arm:concatenate_chr_splits -
# [-        ] NFC…LOGHARM:quality_control:qc -
# [-        ] NFC…_control:harmonization_log -
# [-        ] NFC…y_control:update_meta_yaml -
# no,other setting
# [chr1, chr12, chr15, chr13, chr19, chr18, chrY, chr14, chr7, chr16, chr3, chr8, chrX, chr5, chrMT, chr21, chr9, chr22, chr10, chr20, chr17, chr2, chr6, chr11, chr4,  is being harmonized]
#
# executor >  local (52)
# [8e/be45ca] NFC…o_build (21001_raw_subset) | 1 of 1 ✔
# [ed/212e22] NFC…s (21001_raw_subset_chr22) | 25 of 25 ✔
# [f9/a85c3e] NFC…nts_sum (21001_raw_subset) | 1 of 1 ✔
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [ff/5495d8] NFC…on (21001_raw_subset_chrY) | 0 of 25
# [-        ] NFC…arm:concatenate_chr_splits -
# [-        ] NFC…LOGHARM:quality_control:qc -
# [-        ] NFC…_control:harmonization_log -
# [-        ] NFC…y_control:update_meta_yaml -
# no,other setting
# [chr1, chr12, chr15, chr13, chr19, chr18, chrY, chr14, chr7, chr16, chr3, chr8, chrX, chr5, chrMT, chr21, chr9, chr22, chr10, chr20, chr17, chr2, chr6, chr11, chr4,  is being harmonized]
#
# executor >  local (52)
# [8e/be45ca] NFC…o_build (21001_raw_subset) | 1 of 1 ✔
# [ed/212e22] NFC…s (21001_raw_subset_chr22) | 25 of 25 ✔
# [f9/a85c3e] NFC…nts_sum (21001_raw_subset) | 1 of 1 ✔
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [ff/5495d8] NFC…on (21001_raw_subset_chrY) | 0 of 25
# [-        ] NFC…arm:concatenate_chr_splits -
# [-        ] NFC…LOGHARM:quality_control:qc -
# [-        ] NFC…_control:harmonization_log -
# [-        ] NFC…y_control:update_meta_yaml -
# no,other setting
# [chr1, chr12, chr15, chr13, chr19, chr18, chrY, chr14, chr7, chr16, chr3, chr8, chrX, chr5, chrMT, chr21, chr9, chr22, chr10, chr20, chr17, chr2, chr6, chr11, chr4,  is being harmonized]
#
# executor >  local (52)
# [8e/be45ca] NFC…o_build (21001_raw_subset) | 1 of 1 ✔
# [ed/212e22] NFC…s (21001_raw_subset_chr22) | 25 of 25 ✔
# [f9/a85c3e] NFC…nts_sum (21001_raw_subset) | 1 of 1 ✔
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [a4/4a5561] NFC…n (21001_raw_subset_chr17) | 0 of 25
# [-        ] NFC…arm:concatenate_chr_splits -
# [-        ] NFC…LOGHARM:quality_control:qc -
# [-        ] NFC…_control:harmonization_log -
# [-        ] NFC…y_control:update_meta_yaml -
# no,other setting
# [chr1, chr12, chr15, chr13, chr19, chr18, chrY, chr14, chr7, chr16, chr3, chr8, chrX, chr5, chrMT, chr21, chr9, chr22, chr10, chr20, chr17, chr2, chr6, chr11, chr4,  is being harmonized]
# ERROR ~ Error executing process > 'NFCORE_GWASCATALOGHARM:GWASCATALOGHARM:main_harm:harmonization (21001_raw_subset_chr17)'
#
# Caused by:
#   Process `NFCORE_GWASCATALOGHARM:GWASCATALOGHARM:main_harm:harmonization (21001_raw_subset_chr17)` terminated with an error exit status (1)
#
#
# Command executed:
#
#   coordinate_system=$(grep coordinate_system 21001_raw_subset.tsv.gz-meta.yaml | awk -F ":" '{print $2}' | tr -d "[:blank:]" )
#   if test -z "$coordinate_system"; then coordinate="1-based"; else coordinate=$coordinate_system; fi
#
#   header_args=$(utils.py -f 17.merged -harm_args);
#
#   main_pysam.py     --sumstats 17.merged     --vcf /mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser/gwas-ref/homo_sapiens-chr17.vcf.gz     --hm_sumstats chr17.merged_unsorted.hm     --hm_statfile chr17.merged.log.tsv.gz     $header_args     --na_rep_in NA     --na_rep_out NA     --coordinate $coordinate     --palin_mode drop;
#
#   chr=$(awk -v RS='	' '/chromosome/{print NR; exit}' chr17.merged_unsorted.hm)
#   pos=$(awk -v RS='	' '/base_pair_location/{print NR; exit}' chr17.merged_unsorted.hm)
#
#   head -n1 chr17.merged_unsorted.hm > chr17.merged.hm;
#   tail -n+2 chr17.merged_unsorted.hm | sort -n -k$chr -k$pos -T$PWD >> chr17.merged.hm
#
# Command exit status:
#   1
#
# Command output:
#   (empty)
#
# Command error:
#   INFO:    /etc/singularity/ exists; cleanup by system administrator is not complete (see https://apptainer.org/docs/admin/latest/singularity_migration.html)
#   INFO:    Environment variable SINGULARITYENV_NXF_TASK_WORKDIR is set, but APPTAINERENV_NXF_TASK_WORKDIR is preferred
#   Traceback (most recent call last):
#     File "/home/ofgeha/.nextflow/assets/EBISPOT/gwas-sumstats-harmoniser/bin/main_pysam.py", line 780, in <module>
#       main()
#     File "/home/ofgeha/.nextflow/assets/EBISPOT/gwas-sumstats-harmoniser/bin/main_pysam.py", line 34, in main
#       out_header = SumStatsTable(sumstats_file=args.sumstats)._set_header_order()
#     File "/usr/local/lib/python3.9/site-packages/gwas_sumstats_tools/interfaces/data_table.py", line 149, in _set_header_order
#       header_order.extend([h for h in self.FIELDS_OPTIONAL if h in self.header()])
#     File "/usr/local/lib/python3.9/site-packages/gwas_sumstats_tools/interfaces/data_table.py", line 149, in <listcomp>
#       header_order.extend([h for h in self.FIELDS_OPTIONAL if h in self.header()])
#     File "/usr/local/lib/python3.9/site-packages/gwas_sumstats_tools/interfaces/data_table.py", line 187, in header
#       if self.is_table_content():
#     File "/usr/local/lib/python3.9/site-packages/gwas_sumstats_tools/interfaces/data_table.py", line 82, in is_table_content
#       return etl.nrows(self.head_table(nrows=1)) > 0
#     File "/usr/local/lib/python3.9/site-packages/petl/util/counting.py", line 22, in nrows
#       return sum(1 for _ in data(table))
#     File "/usr/local/lib/python3.9/site-packages/petl/util/counting.py", line 22, in <genexpr>
#       return sum(1 for _ in data(table))
#     File "/usr/local/lib/python3.9/site-packages/petl/transform/basics.py", line 751, in iterrowslice
#       it = iter(source)
#   TypeError: 'NoneType' object is not iterable
#
# Work dir:
#   /mnt/hdd_1/ofgeha/galaxy-gwas-tools/Gwaslab/work/a4/4a556108eab59936f46002bf8a7197
#
# Container:
#   /mnt/hdd_1/ofgeha/galaxy-gwas-tools/Gwaslab/work/singularity/ebispot-gwas-sumstats-harmoniser-latest.img
#
# Tip: you can replicate the issue by changing to the process work dir and entering the command `bash .command.run`
#
#  -- Check '.nextflow.log' file for details
#
# executor >  local (52)
# [8e/be45ca] NFC…o_build (21001_raw_subset) | 1 of 1 ✔
# [ed/212e22] NFC…s (21001_raw_subset_chr22) | 25 of 25 ✔
# [f9/a85c3e] NFC…nts_sum (21001_raw_subset) | 1 of 1 ✔
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [ff/5495d8] NFC…on (21001_raw_subset_chrY) | 0 of 25
# [-        ] NFC…arm:concatenate_chr_splits -
# [-        ] NFC…LOGHARM:quality_control:qc -
# [-        ] NFC…_control:harmonization_log -
# [-        ] NFC…y_control:update_meta_yaml -
# no,other setting
# [chr1, chr12, chr15, chr13, chr19, chr18, chrY, chr14, chr7, chr16, chr3, chr8, chrX, chr5, chrMT, chr21, chr9, chr22, chr10, chr20, chr17, chr2, chr6, chr11, chr4,  is being harmonized]
# WARN: Killing running tasks (24)
# ERROR ~ Error executing process > 'NFCORE_GWASCATALOGHARM:GWASCATALOGHARM:main_harm:harmonization (21001_raw_subset_chr17)'
#
# Caused by:
#   Process `NFCORE_GWASCATALOGHARM:GWASCATALOGHARM:main_harm:harmonization (21001_raw_subset_chr17)` terminated with an error exit status (1)
#
#
# Command executed:
#
#   coordinate_system=$(grep coordinate_system 21001_raw_subset.tsv.gz-meta.yaml | awk -F ":" '{print $2}' | tr -d "[:blank:]" )
#   if test -z "$coordinate_system"; then coordinate="1-based"; else coordinate=$coordinate_system; fi
#
#   header_args=$(utils.py -f 17.merged -harm_args);
#
#   main_pysam.py     --sumstats 17.merged     --vcf /mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser/gwas-ref/homo_sapiens-chr17.vcf.gz     --hm_sumstats chr17.merged_unsorted.hm     --hm_statfile chr17.merged.log.tsv.gz     $header_args     --na_rep_in NA     --na_rep_out NA     --coordinate $coordinate     --palin_mode drop;
#
#   chr=$(awk -v RS='	' '/chromosome/{print NR; exit}' chr17.merged_unsorted.hm)
#   pos=$(awk -v RS='	' '/base_pair_location/{print NR; exit}' chr17.merged_unsorted.hm)
#
#   head -n1 chr17.merged_unsorted.hm > chr17.merged.hm;
#   tail -n+2 chr17.merged_unsorted.hm | sort -n -k$chr -k$pos -T$PWD >> chr17.merged.hm
#
# Command exit status:
#   1
#
# Command output:
#   (empty)
#
# Command error:
#   INFO:    /etc/singularity/ exists; cleanup by system administrator is not complete (see https://apptainer.org/docs/admin/latest/singularity_migration.html)
#   INFO:    Environment variable SINGULARITYENV_NXF_TASK_WORKDIR is set, but APPTAINERENV_NXF_TASK_WORKDIR is preferred
#   Traceback (most recent call last):
#     File "/home/ofgeha/.nextflow/assets/EBISPOT/gwas-sumstats-harmoniser/bin/main_pysam.py", line 780, in <module>
#       main()
#     File "/home/ofgeha/.nextflow/assets/EBISPOT/gwas-sumstats-harmoniser/bin/main_pysam.py", line 34, in main
#       out_header = SumStatsTable(sumstats_file=args.sumstats)._set_header_order()
#     File "/usr/local/lib/python3.9/site-packages/gwas_sumstats_tools/interfaces/data_table.py", line 149, in _set_header_order
#       header_order.extend([h for h in self.FIELDS_OPTIONAL if h in self.header()])
#     File "/usr/local/lib/python3.9/site-packages/gwas_sumstats_tools/interfaces/data_table.py", line 149, in <listcomp>
#       header_order.extend([h for h in self.FIELDS_OPTIONAL if h in self.header()])
#     File "/usr/local/lib/python3.9/site-packages/gwas_sumstats_tools/interfaces/data_table.py", line 187, in header
#       if self.is_table_content():
#     File "/usr/local/lib/python3.9/site-packages/gwas_sumstats_tools/interfaces/data_table.py", line 82, in is_table_content
#       return etl.nrows(self.head_table(nrows=1)) > 0
#     File "/usr/local/lib/python3.9/site-packages/petl/util/counting.py", line 22, in nrows
#       return sum(1 for _ in data(table))
#     File "/usr/local/lib/python3.9/site-packages/petl/util/counting.py", line 22, in <genexpr>
#       return sum(1 for _ in data(table))
#     File "/usr/local/lib/python3.9/site-packages/petl/transform/basics.py", line 751, in iterrowslice
#       it = iter(source)
#   TypeError: 'NoneType' object is not iterable
#
# Work dir:
#   /mnt/hdd_1/ofgeha/galaxy-gwas-tools/Gwaslab/work/a4/4a556108eab59936f46002bf8a7197
#
# Container:
#   /mnt/hdd_1/ofgeha/galaxy-gwas-tools/Gwaslab/work/singularity/ebispot-gwas-sumstats-harmoniser-latest.img
#
# Tip: you can replicate the issue by changing to the process work dir and entering the command `bash .command.run`
#
#  -- Check '.nextflow.log' file for details
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[4], line 14
#       3 cmd = [
#       4     "nextflow", "run", "EBISPOT/gwas-sumstats-harmoniser",
#       5     "-r", "v1.1.10",
#    (...)     10     "-resume"
#      11 ]
#      13 print(" ".join(cmd))
# ---> 14 subprocess.run(cmd, check=True)
#
# File /usr/lib/python3.12/subprocess.py:571, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     569     retcode = process.poll()
#     570     if check and retcode:
# --> 571         raise CalledProcessError(retcode, process.args,
#     572                                  output=stdout, stderr=stderr)
#     573 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['nextflow', 'run', 'EBISPOT/gwas-sumstats-harmoniser', '-r', 'v1.1.10', '--ref', '/mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser/gwas-ref', '--harm', '--file', '/mnt/hdd_1/ofgeha/test/21001_raw_subset.tsv.gz', '-profile', 'standard,singularity', '-resume']' returned non-zero exit status 1.

# %%
import subprocess
import os
from pathlib import Path

# Set your paths
input_file = "/mnt/hdd_1/ofgeha/test/21001_raw.gwas.imputed_v3.both_sexes.tsv.gz"
ref_dir = "/mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser/gwas-ref"
output_dir = "./gwas_output"  # or wherever you want output

# Create command
command = [
    "nextflow", "run", "EBISPOT/gwas-sumstats-harmoniser",
    "-r", "v1.1.10",
    "--ref", ref_dir,
    "--harm",
    "--file", input_file,
    "--chromlist", "22,",
    "--terminate_error", "ignore",
    "-profile", "standard,singularity",
    "-resume"
]

# Run the command
print("Running Nextflow pipeline...")
result = subprocess.run(command, capture_output=True, text=True)

# Print output
print("STDOUT:", result.stdout)
print("STDERR:", result.stderr)
print("Return code:", result.returncode)

# %%
# %%bash
# cd /mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser
#
# nextflow run EBISPOT/gwas-sumstats-harmoniser \
#   -r v1.1.10 \
#   --ref /mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser/gwas-ref \
#   --harm \
#   --file /mnt/hdd_1/ofgeha/test/21001_raw.gwas.imputed_v3.both_sexes.tsv.gz \
#   --chromlist '22,' \
#   --terminate_error ignore \
#   -profile standard,singularity \
#   -resume

# %%
import subprocess
import sys
import time
from IPython.display import clear_output

def run_nextflow_pipeline():
    """Run Nextflow pipeline with real-time output"""
    
    cmd = [
        "nextflow", "run", "EBISPOT/gwas-sumstats-harmoniser",
        "-r", "v1.1.10",
        "--ref", "/mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser/gwas-ref",
        "--harm",
        "--file", "/mnt/hdd_1/ofgeha/test/21001_raw.gwas.imputed_v3.both_sexes.tsv.gz",
        "--chromlist", "16,",
        "--terminate_error", "ignore",
        "-profile", "standard,singularity",
        "-resume"
    ]
    
    print(f"Running command: {' '.join(cmd)}")
    print("="*60)
    
    # Run with real-time output
    process = subprocess.Popen(
        cmd,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        bufsize=1,
        universal_newlines=True
    )
    
    # Print output in real-time
    while True:
        output = process.stdout.readline()
        if output == '' and process.poll() is not None:
            break
        if output:
            print(output.strip())
    
    return process.poll()

# Run the pipeline
exit_code = run_nextflow_pipeline()
print(f"\nPipeline finished with exit code: {exit_code}")
