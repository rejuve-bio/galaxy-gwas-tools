# %%
import gwaslab as gl

# %%
mysumstats = gl.Sumstats(
    "/mnt/hdd_1/ofgeha/galaxy-gwas-tools/Data/21001_raw.gwas.imputed_v3.both_sexes.tsv.bgz",
    snpid="SNPID",
    chrom="CHR",
    pos="POS",
    ea="EA",            
    nea="NEA",          
    eaf="EAF",          
    beta="BETA",
    se="SE",
    p="P",
    verbose=True,
    readargs={'sep': '\t'}
)
# Out:
# 2026/03/07 06:28:13 GWASLab v4.0.4 https://cloufield.github.io/gwaslab/
# 2026/03/07 06:28:13 (C) 2022-2026, Yunye He, Kamatani Lab, GPL-3.0 license, gwaslab@gmail.com
# 2026/03/07 06:28:13 Python version: 3.12.3 (main, Jan 22 2026, 20:57:42) [GCC 13.3.0]
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 mysumstats = gl.Sumstats(
#       2     "/mnt/hdd_1/ofgeha/galaxy-gwas-tools/Data/21001_raw.gwas.imputed_v3.both_sexes.tsv.bgz",
#       3     snpid="SNPID",
#       4     chrom="CHR",
#       5     pos="POS",
#       6     ea="EA",
#       7     nea="NEA",
#       8     eaf="EAF",
#       9     beta="BETA",
#      10     se="SE",
#      11     p="P",
#      12     verbose=True,
#      13     readargs={'sep': '\t'}
#      14 )
#
# File /mnt/hdd_1/ofgeha/galaxy-gwas-tools/.venv/lib/python3.12/site-packages/gwaslab/g_Sumstats.py:251, in Sumstats.__init__(self, sumstats, fmt, tab_fmt, snpid, rsid, chrom, pos, ea, nea, ref, alt, eaf, neaf, maf, n, beta, se, chisq, z, f, t, p, q, mlog10p, test, info, OR, OR_95L, OR_95U, beta_95L, beta_95U, HR, HR_95L, HR_95U, ncase, ncontrol, neff, i2, phet, dof, snpr2, status, other, exclude, include, chrom_pat, snpid_pat, direction, verbose, study, trait, build, species, readargs, **kwreadargs)
#     248 self._last_shape = None
#     250 #preformat the data
# --> 251 self.data  = _preformat(
#     252   sumstats=sumstats,
#     253   fmt=fmt,
#     254   tab_fmt = tab_fmt,
#     255   snpid=snpid,
#     256   rsid=rsid,
#     257   chrom=chrom,
#     258   pos=pos,
#     259   ea=ea,
#     260   nea=nea,
#     261   ref=ref,
#     262   alt=alt,
#     263   eaf=eaf,
#     264   neaf=neaf,
#     265   maf=maf,
#     266   n=n,
#     267   beta=beta,
#     268   se=se,
#     269   chisq=chisq,
#     270   z=z,
#     271   f=f,
#     272   t=t,
#     273   p=p,
#     274   q=q,
#     275   mlog10p=mlog10p,
#     276   test=test,
#     277   info=info,
#     278   OR=OR,
#     279   OR_95L=OR_95L,
#     280   OR_95U=OR_95U,
#     281   beta_95L=beta_95L,
#     282   beta_95U=beta_95U,
#     283   HR=HR,
#     284   HR_95L=HR_95L,
#     285   HR_95U=HR_95U,
#     286   i2=i2,
#     287   phet=phet,
#     288   dof=dof,
#     289   snpr2=snpr2,
#     290   ncase=ncase,
#     291   ncontrol=ncontrol,
#     292   neff=neff,
#     293   direction=direction,
#     294   study=study,
#     295   build=build,
#     296   trait=trait,
#     297   status=status,
#     298   other=other,
#     299   exclude=exclude,
#     300   include=include,
#     301   chrom_pat=chrom_pat,
#     302   snpid_pat=snpid_pat,
#     303   verbose=verbose,
#     304   log=self.log,
#     305   readargs=readargs,
#     306   **kwreadargs)
#     308 # meta information
#     309 self.meta = _init_meta()
#
# File /mnt/hdd_1/ofgeha/galaxy-gwas-tools/.venv/lib/python3.12/site-packages/gwaslab/io/io_preformat_input.py:620, in _preformat(sumstats, fmt, tab_fmt, snpid, rsid, chrom, pos, ea, nea, ref, alt, eaf, neaf, maf, n, beta, se, chisq, z, f, t, p, q, mlog10p, test, info, OR, OR_95L, OR_95U, beta_95L, beta_95U, HR, HR_95L, HR_95U, i2, snpr2, phet, dof, ncase, ncontrol, neff, direction, status, study, trait, build, other, exclude, include, chrom_pat, snpid_pat, verbose, log, readargs, **kwreadargs)
#     617 dtype_dictionary = {}
#     619 # Step 4: Check path and header, get available columns
# --> 620 inpath, inpath_chr_list, inpath_chr_num_list, format_cols, raw_cols, usecols, dtype_dictionary = _check_path_and_header(
#     621     sumstats, fmt, meta_data, readargs, usecols, dtype_dictionary, rename_dictionary, log, verbose
#     622 )
#     624 # Step 5: Build column mappings from user parameters
#     625 column_params = {
#     626     'snpid': snpid, 'rsid': rsid, 'chrom': chrom, 'pos': pos, 'ea': ea, 'nea': nea,
#     627     'ref': ref, 'alt': alt, 'eaf': eaf, 'neaf': neaf, 'maf': maf, 'n': n,
#    (...)    633     'dof': dof, 'direction': direction, 'status': status, 'other': other
#     634 }
#
# File /mnt/hdd_1/ofgeha/galaxy-gwas-tools/.venv/lib/python3.12/site-packages/gwaslab/io/io_preformat_input.py:904, in _check_path_and_header(sumstats, fmt, meta_data, readargs, usecols, dtype_dictionary, rename_dictionary, log, verbose)
#     901 inpath = sumstats
#     903 try:
# --> 904     format_cols, raw_cols, inpath_chr_list, inpath_chr_num_list = _process_inpath_and_load_header(inpath, fmt, meta_data,  readargs, log, verbose)
#     906 except (FileNotFoundError, IndexError):
#     907     log.warning("Loading {} failed...Tesing if compressed/uncompressed...".format(inpath),verbose=verbose)
#
# File /mnt/hdd_1/ofgeha/galaxy-gwas-tools/.venv/lib/python3.12/site-packages/gwaslab/io/io_preformat_input.py:986, in _process_inpath_and_load_header(inpath, fmt, meta_data, readargs, log, verbose)
#     982 else:
#     983 ##### loading data from tabular file#################################################
#     984 #if file not found, FileNotFoundError
#     985     readargs_header = _get_readargs_header(inpath = inpath, readargs = readargs)
# --> 986     row_one = pd.read_table(inpath,**readargs_header)
#     987     raw_cols = row_one.columns
#     989 if fmt=="vcf":
#     990     # expanded
#
# File /mnt/hdd_1/ofgeha/galaxy-gwas-tools/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1405, in read_table(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1392 kwds_defaults = _refine_defaults_read(
#    1393     dialect,
#    1394     delimiter,
#    (...)   1401     dtype_backend=dtype_backend,
#    1402 )
#    1403 kwds.update(kwds_defaults)
# -> 1405 return _read(filepath_or_buffer, kwds)
#
# File /mnt/hdd_1/ofgeha/galaxy-gwas-tools/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /mnt/hdd_1/ofgeha/galaxy-gwas-tools/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /mnt/hdd_1/ofgeha/galaxy-gwas-tools/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File /mnt/hdd_1/ofgeha/galaxy-gwas-tools/.venv/lib/python3.12/site-packages/pandas/io/parsers/c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File pandas/_libs/parsers.pyx:574, in pandas._libs.parsers.TextReader.__cinit__()
#
# File pandas/_libs/parsers.pyx:663, in pandas._libs.parsers.TextReader._get_header()
#
# File pandas/_libs/parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File pandas/_libs/parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File pandas/_libs/parsers.pyx:2053, in pandas._libs.parsers.raise_parser_error()
#
# File <frozen codecs>:322, in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x8b in position 1: invalid start byte

# %%
mysumstats.data
# Out:
#                       SNPID  CHR        POS EA  NEA   STATUS       EAF  \
# 0               1:69487:G:A    1      69487  A    G  9999999  0.999994
# 1               1:69569:T:C    1      69569  C    T  9999999  0.999812
# 2              1:139853:C:T    1     139853  T    C  9999999  0.999994
# 3             1:692794:CA:C    1     692794  C   CA  9999999  0.889410
# 4              1:693731:A:G    1     693731  G    A  9999999  0.884233
# ...                     ...  ...        ... ..  ...      ...       ...
# 13779880    X:154929412:C:T   23  154929412  T    C  9999999  0.754527
# 13779881   X:154929637:CT:C   23  154929637  C   CT  9999999  0.770274
# 13779882  X:154929952:CAA:C   23  154929952  C  CAA  9999999  0.760570
# 13779883    X:154930230:A:G   23  154930230  G    A  9999999  0.754113
# 13779884    X:154930487:T:A   23  154930487  A    T  9999999  0.980441
#
#               BETA        SE         P
# 0        -2.715450  2.360060  0.249902
# 1        -0.484284  0.423462  0.252778
# 2        -2.703560  2.360130  0.251997
# 3        -0.016436  0.019585  0.401342
# 4        -0.004255  0.018507  0.818155
# ...            ...       ...       ...
# 13779880 -0.016260  0.010723  0.129427
# 13779881 -0.027098  0.011190  0.015456
# 13779882 -0.020494  0.011278  0.069202
# 13779883 -0.016347  0.010721  0.127334
# 13779884  0.007107  0.036783  0.846790
#
# [13779885 rows x 10 columns]

# %%
# valid_bases = {'A', 'T', 'C', 'G'}
# mysumstats.data = mysumstats.data[
#     mysumstats.data["EA"].isin(valid_bases) & 
#     mysumstats.data["NEA"].isin(valid_bases)
# ].copy()

mysumstats.data.attrs["build"] = "38"

mysumstats.harmonize(
    ref_seq="/mnt/hdd_1/ofgeha/galaxy-gwas-tools/Data/hg38.fa",
    ref_infer="/mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser/gwas-ref/homo_sapiens-chr*.vcf.gz",
    ref_alt_freq="AF",
    threads=6,
    remove=True
)
# Out:
# 2026/03/07 06:24:23 Start to check SNPID/rsID ...(v4.0.4)
# 2026/03/07 06:24:23  -Checking SNPID data type...
# 2026/03/07 06:24:23  -Checking if SNPID contains NA strings :na,NA,Na,Nan,NaN,<NA>,null,NULL,#N/A,#VALUE!,N/A,n/a,missing,...
# 2026/03/07 06:24:24  -Checking if SNPID is CHR:POS:NEA:EA...(separator: - ,: , _)
# 2026/03/07 06:24:28 Finished checking SNPID/rsID.
# 2026/03/07 06:24:28 Start to fix chromosome notation (CHR) ...(v4.0.4)
# 2026/03/07 06:24:28  -Checking CHR data type...
# 2026/03/07 06:24:31  -Variants with standardized chromosome notation: 13779885
# 2026/03/07 06:24:31  -All CHR are already fixed...
# 2026/03/07 06:24:32 Finished fixing chromosome notation (CHR).
# 2026/03/07 06:24:32 Start to fix basepair positions (POS) ...(v4.0.4)
# 2026/03/07 06:24:32  -Trying to convert datatype for POS: Int64 -> Int64...
# 2026/03/07 06:24:33  -Position bound:(0 , 250,000,000)
# 2026/03/07 06:24:33  -No outlier variants were removed.
# 2026/03/07 06:24:35  -Removed variants with bad positions: 0
# 2026/03/07 06:24:35 Finished fixing basepair positions (POS).
# 2026/03/07 06:24:35 Start to fix alleles (EA and NEA) ...(v4.0.4)
# 2026/03/07 06:24:35  -Converted all bases to string datatype and UPPERCASE
# 2026/03/07 06:24:37  -Variants with bad EA: 0
# 2026/03/07 06:24:37  -Variants with bad NEA: 0
# 2026/03/07 06:24:37  -Variants with NA for EA or NEA: 0
# 2026/03/07 06:24:37  -Variants with same EA and NEA: 1950599
# 2026/03/07 06:24:46 Finished fixing alleles (EA and NEA).
# 2026/03/07 06:24:46 Start to perform sanity check for statistics ...(v4.0.4)
# 2026/03/07 06:24:46  -Comparison tolerance for floats: 1e-07
# 2026/03/07 06:24:46  -Checking if any columns are empty...
# 2026/03/07 06:24:48  -Checking if -1e-07 < EAF < 1.0000001 : removed 0 variants.
# 2026/03/07 06:24:50  -Checking if -1e-07 < P < 1.0000001 : removed 0 variants.
# 2026/03/07 06:24:51  -Checking if -100.0000001 < BETA < 100.0000001 : removed 0 variants.
# 2026/03/07 06:24:52  -Checking if -1e-07 < SE < inf : removed 0 variants.
# 2026/03/07 06:24:52  -Checking STATUS and converting STATUS to Int64....
# 2026/03/07 06:24:52  -No variants were removed with bad statistics in total.
# 2026/03/07 06:24:52 Finished sanity check for statistics.
# 2026/03/07 06:24:52 Start to normalize indels ...(v4.0.4)
# 2026/03/07 06:24:52  -Number of threads/cores to use: 6
# 2026/03/07 06:24:52  -No available variants to normalize..
# 2026/03/07 06:24:52 Finished normalizing indels.
# 2026/03/07 06:24:52 Start to reorder the columns ...(v4.0.4)
# 2026/03/07 06:24:52  -Reordering columns to    : SNPID,CHR,POS,EA,NEA,STATUS,EAF,BETA,SE,P
# 2026/03/07 06:24:53 Finished reordering the columns.
# 2026/03/07 06:24:53 Start to sort the genome coordinates ...(v4.0.4)
# 2026/03/07 06:25:00 Finished sorting coordinates.
# 2026/03/07 06:25:00 Start to check if NEA is aligned with reference sequence ...(v4.0.4)
# 2026/03/07 06:25:00  -Reference genome FASTA file: /mnt/hdd_1/ofgeha/galaxy-gwas-tools/Data/hg38.fa
# 2026/03/07 06:25:08    -Loading and building numpy fasta records:
# 2026/03/07 06:25:14  -Variants allele on given reference sequence :  0
# 2026/03/07 06:25:14  -Variants flipped :  0
# 2026/03/07 06:25:14   -Raw Matching rate :  0.00%
# 2026/03/07 06:25:14 #WARNING! Matching rate is low, please check if the right reference genome is used.
# 2026/03/07 06:25:14  -Variants inferred reverse_complement :  0
# 2026/03/07 06:25:14  -Variants inferred reverse_complement_flipped :  0
# 2026/03/07 06:25:14  -Both allele on genome + unable to distinguish :  0
# 2026/03/07 06:25:14  -Variants not on given reference sequence :  0
# 2026/03/07 06:25:14 Finished checking if NEA is aligned with reference sequence.
# 2026/03/07 06:25:14 Start to adjust statistics based on STATUS code ...(v4.0.4)
# 2026/03/07 06:25:14  -No statistics have been changed.
# 2026/03/07 06:25:14 Finished adjusting statistics based on STATUS code.
# 2026/03/07 06:25:15 Start to infer strand for palindromic SNPs/align indistinguishable indels ...(v4.0.4)
# 2026/03/07 06:25:15  -Number of threads/cores to use: 6
# 2026/03/07 06:25:15 #WARNING! Reference file not found: /mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser/gwas-ref/homo_sapiens-chr*.vcf.gz. Using default format.
# 2026/03/07 06:25:15  -Field for alternative allele frequency in VCF INFO: AF
# 2026/03/07 06:25:15  -Identified  1660921  palindromic SNPs...
# 2026/03/07 06:25:15  -After filtering by MAF<= 0.4 , 0 palindromic SNPs with unknown strand will be inferred...
# 2026/03/07 06:25:15 #WARNING! No palindromic variants available for checking.
# 2026/03/07 06:25:16   -Non-palindromic :  9169689
# 2026/03/07 06:25:17   -Palindromic SNPs on + strand:  0
# 2026/03/07 06:25:17   -Palindromic SNPs on - strand and needed to be flipped: 0
# 2026/03/07 06:25:18   -Palindromic SNPs with MAF not available to infer :  86113
# 2026/03/07 06:25:19   -Palindromic SNPs lacking reference matches, or with reference ALT unavailable or above MAF threshold for inference :  0
# 2026/03/07 06:25:19  -Identified  0  indistinguishable Indels...
# 2026/03/07 06:25:19 #WARNING! No indistinguishable indels available for checking.
# 2026/03/07 06:25:19 Finished inferring strand for palindromic SNPs/align indistinguishable indels.
# 2026/03/07 06:25:19 Start to adjust statistics based on STATUS code ...(v4.0.4)
# 2026/03/07 06:25:19  -No statistics have been changed.
# 2026/03/07 06:25:19 Finished adjusting statistics based on STATUS code.
# 2026/03/07 06:25:20 Start to remove duplicated/multiallelic variants ...(v4.0.4)
# 2026/03/07 06:25:20  -Removing mode:dm
# 2026/03/07 06:25:20 Start to sort the sumstats using P ...
# 2026/03/07 06:25:23 Start to remove duplicated variants based on snpid ...(v4.0.4)
# 2026/03/07 06:25:23  -Which variant to keep:  first
# 2026/03/07 06:25:34  -Removed variants based on SNPID: 0
# 2026/03/07 06:25:34 Start to remove duplicated variants based on CHR,POS,EA and NEA ...
# 2026/03/07 06:25:34  -Which variant to keep:  first
# 2026/03/07 06:25:42  -Removed variants based on CHR,POS,EA and NEA: 978
# 2026/03/07 06:25:42 Start to remove multiallelic variants based on chr:pos ...
# 2026/03/07 06:25:42  -Current Dataframe shape : 13778907 x 10 ; Memory usage: 1043.31 MB
# 2026/03/07 06:25:42  -Which variant to keep:  first
# 2026/03/07 06:25:52  -Removed variants multiallelic variants: 17251
# 2026/03/07 06:25:52  -Removed variants in total: 18229
# 2026/03/07 06:25:52  -Sort the coordinates based on CHR and POS...
# 2026/03/07 06:26:03 Finished removing duplicated/multiallelic variants.
# 2026/03/07 06:26:03 Start to sort the genome coordinates ...(v4.0.4)
# 2026/03/07 06:26:10 Finished sorting coordinates.
# 2026/03/07 06:26:10 Start to reorder the columns ...(v4.0.4)
# 2026/03/07 06:26:10  -Reordering columns to    : SNPID,CHR,POS,EA,NEA,STATUS,EAF,BETA,SE,P
# 2026/03/07 06:26:10 Finished reordering the columns.
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>SNPID</th>
#       <th>CHR</th>
#       <th>POS</th>
#       <th>EA</th>
#       <th>NEA</th>
#       <th>STATUS</th>
#       <th>EAF</th>
#       <th>BETA</th>
#       <th>SE</th>
#       <th>P</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1:69487:G:A</td>
#       <td>1</td>
#       <td>69487</td>
#       <td>A</td>
#       <td>G</td>
#       <td>9960090</td>
#       <td>0.999994</td>
#       <td>-2.715450</td>
#       <td>2.360060</td>
#       <td>0.249902</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1:69569:T:C</td>
#       <td>1</td>
#       <td>69569</td>
#       <td>C</td>
#       <td>T</td>
#       <td>9960090</td>
#       <td>0.999812</td>
#       <td>-0.484284</td>
#       <td>0.423462</td>
#       <td>0.252778</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1:139853:C:T</td>
#       <td>1</td>
#       <td>139853</td>
#       <td>T</td>
#       <td>C</td>
#       <td>9960090</td>
#       <td>0.999994</td>
#       <td>-2.703560</td>
#       <td>2.360130</td>
#       <td>0.251997</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1:692794:CA:C</td>
#       <td>1</td>
#       <td>692794</td>
#       <td>C</td>
#       <td>CA</td>
#       <td>9960399</td>
#       <td>0.889410</td>
#       <td>-0.016436</td>
#       <td>0.019585</td>
#       <td>0.401342</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1:693731:A:G</td>
#       <td>1</td>
#       <td>693731</td>
#       <td>G</td>
#       <td>A</td>
#       <td>9960090</td>
#       <td>0.884233</td>
#       <td>-0.004255</td>
#       <td>0.018507</td>
#       <td>0.818155</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>13761651</th>
#       <td>X:154929412:C:T</td>
#       <td>23</td>
#       <td>154929412</td>
#       <td>T</td>
#       <td>C</td>
#       <td>9960090</td>
#       <td>0.754527</td>
#       <td>-0.016260</td>
#       <td>0.010723</td>
#       <td>0.129427</td>
#     </tr>
#     <tr>
#       <th>13761652</th>
#       <td>X:154929637:CT:C</td>
#       <td>23</td>
#       <td>154929637</td>
#       <td>C</td>
#       <td>CT</td>
#       <td>9960399</td>
#       <td>0.770274</td>
#       <td>-0.027098</td>
#       <td>0.011190</td>
#       <td>0.015456</td>
#     </tr>
#     <tr>
#       <th>13761653</th>
#       <td>X:154929952:CAA:C</td>
#       <td>23</td>
#       <td>154929952</td>
#       <td>C</td>
#       <td>CAA</td>
#       <td>9960399</td>
#       <td>0.760570</td>
#       <td>-0.020494</td>
#       <td>0.011278</td>
#       <td>0.069202</td>
#     </tr>
#     <tr>
#       <th>13761654</th>
#       <td>X:154930230:A:G</td>
#       <td>23</td>
#       <td>154930230</td>
#       <td>G</td>
#       <td>A</td>
#       <td>9960090</td>
#       <td>0.754113</td>
#       <td>-0.016347</td>
#       <td>0.010721</td>
#       <td>0.127334</td>
#     </tr>
#     <tr>
#       <th>13761655</th>
#       <td>X:154930487:T:A</td>
#       <td>23</td>
#       <td>154930487</td>
#       <td>A</td>
#       <td>T</td>
#       <td>9960099</td>
#       <td>0.980441</td>
#       <td>0.007107</td>
#       <td>0.036783</td>
#       <td>0.846790</td>
#     </tr>
#   </tbody>
# </table>
# <p>13761656 rows × 10 columns</p>
# </div>

# %%
mysumstats.liftover(from_build="19", to_build="38")
# Out:
# 2026/03/07 06:22:17 Start to perform liftover ...(v4.0.4)
# 2026/03/07 06:22:17 No records in config file. Please download first.
# 2026/03/07 06:22:17 37to38  is not available. Please use check_available_ref() to check available reference files.
# 2026/03/07 06:22:17 No records in config file. Please download first.
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# File /mnt/hdd_1/ofgeha/galaxy-gwas-tools/.venv/lib/python3.12/site-packages/gwaslab/hm/hm_liftover_v2.py:162, in _liftover_variant(sumstats_obj, chain_path, from_build, to_build, chrom, pos, status, out_chrom_col, out_pos_col, out_strand_col, one_based_input, one_based_output, remove, filter_by_status, verbose, log)
#     161 if chain_path is None or chain_path == False:
# --> 162     lifter_from_build = _process_build(from_build, log=log, verbose=False)
#     163     lifter_to_build = _process_build(to_build, log=log, verbose=False)
#
# UnboundLocalError: cannot access local variable '_process_build' where it is not associated with a value
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 mysumstats.liftover(from_build="37", to_build="38")
#
# File /mnt/hdd_1/ofgeha/galaxy-gwas-tools/.venv/lib/python3.12/site-packages/gwaslab/g_Sumstats.py:560, in Sumstats.liftover(self, to_build, from_build, chain_path, **kwargs)
#     558     from_build = self.build
#     559 kwargs = remove_overlapping_kwargs(kwargs, {"from_build", "to_build", "chain_path", "log"})
# --> 560 self.data = _liftover_variant(self, from_build=from_build, to_build=to_build, chain_path=chain_path, log=self.log, **kwargs)
#
# File /mnt/hdd_1/ofgeha/galaxy-gwas-tools/.venv/lib/python3.12/site-packages/gwaslab/qc/qc_decorator.py:206, in with_logging.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     202         pass
#     204 if is_enough_col==True:
#     205     # Execute the original function
# --> 206     result = func(*args, **kwargs)
#     207 else:
#     208     # not enough cols, return sumstats
#     209     return sumstats
#
# File /mnt/hdd_1/ofgeha/galaxy-gwas-tools/.venv/lib/python3.12/site-packages/gwaslab/hm/hm_liftover_v2.py:175, in _liftover_variant(sumstats_obj, chain_path, from_build, to_build, chrom, pos, status, out_chrom_col, out_pos_col, out_strand_col, one_based_input, one_based_output, remove, filter_by_status, verbose, log)
#     173         log.log_operation("Using chain file: {}".format(chain_path), verbose=verbose)
#     174 except Exception as e:
# --> 175     lifter_from_build = _process_build(from_build, log=log, verbose=False)
#     176     lifter_to_build = _process_build(to_build, log=log, verbose=False)
#     177     raise ValueError("No available chain file for {} -> {}. Error: {}".format(lifter_from_build, lifter_to_build, str(e)))
#
# UnboundLocalError: cannot access local variable '_process_build' where it is not associated with a value

# %%
mysumstats = gl.Sumstats(
    "/mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser/Data/21001_raw.gwas.imputed_v3.both_sexes.tsv",
    fmt="auto")
# Out:
# 2026/03/07 08:06:33 GWASLab v4.0.4 https://cloufield.github.io/gwaslab/
# 2026/03/07 08:06:33 (C) 2022-2026, Yunye He, Kamatani Lab, GPL-3.0 license, gwaslab@gmail.com
# 2026/03/07 08:06:33 Python version: 3.12.3 (main, Jan 22 2026, 20:57:42) [GCC 13.3.0]
# 2026/03/07 08:06:33 Start to load format from formatbook....
# 2026/03/07 08:06:33  -auto format meta info:
# 2026/03/07 08:06:33   - format_name  : auto
# 2026/03/07 08:06:33   - format_separator  : \t
# 2026/03/07 08:06:33   - format_na  : #NA
# 2026/03/07 08:06:33   - format_assumption  : Note: auto-detection assumes A1=EA; Alt=EA and Frq=EAF
# 2026/03/07 08:06:33   - format_version  :  20230328
# 2026/03/07 08:06:33   - Auto-detection mode. Note: auto-detection assumes A1=EA; Alt=EA and Frq=EAF...
# 2026/03/07 08:06:33   - Header conversion source: https://github.com/Cloufield/formatbook/blob/main/formats/auto.json
# 2026/03/07 08:06:33 Start to initialize gl.Sumstats from file :/mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser/Data/21001_raw.gwas.imputed_v3.both_sexes.tsv
# 2026/03/07 08:06:40  -Reading columns          : se,beta
# 2026/03/07 08:06:40  -Renaming columns to      : SE,BETA
# 2026/03/07 08:06:40  -Current Dataframe shape : 13791467  x  2
# 2026/03/07 08:06:41  -Initiating a status column: STATUS ...
# 2026/03/07 08:06:41 #WARNING! Version of genomic coordinates is unknown for homo sapiens (build: 99)...
# 2026/03/07 08:06:41 Start to reorder the columns ...(v4.0.4)
# 2026/03/07 08:06:41  -Reordering columns to    : STATUS,BETA,SE
# 2026/03/07 08:06:43 Finished reordering the columns.
# 2026/03/07 08:06:44 #WARNING!  -No rsID/SNPID and missing CHR/POS; created empty SNPID
# 2026/03/07 08:06:44  -Column  : STATUS BETA    SE      SNPID
# 2026/03/07 08:06:44  -DType   : int64  float64 float64 string
# 2026/03/07 08:06:44  -Verified: T      T       T       T
# 2026/03/07 08:06:45  -Current Dataframe memory usage: 420.88 MB
# 2026/03/07 08:06:45 Finished loading data successfully!

# %%
mysumstats.data
# Out:
#            STATUS        BETA           SE SNPID
# 0         9999999  894.616000  1204.870000  <NA>
# 1         9999999   -2.715450     2.360060  <NA>
# 2         9999999   -0.484284     0.423462  <NA>
# 3         9999999   -2.703560     2.360130  <NA>
# 4         9999999   -0.016436     0.019585  <NA>
# ...           ...         ...          ...   ...
# 13791462  9999999   -0.016260     0.010723  <NA>
# 13791463  9999999   -0.027098     0.011190  <NA>
# 13791464  9999999   -0.020494     0.011278  <NA>
# 13791465  9999999   -0.016347     0.010721  <NA>
# 13791466  9999999    0.007107     0.036783  <NA>
#
# [13791467 rows x 4 columns]

# %%
mysumstats.columns
# Out:
# Index(['STATUS', 'BETA', 'SE', 'SNPID'], dtype='object')

# %%
mysumstats = gl.Sumstats(
    "/mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser/Data/21001_raw.gwas.imputed_v3.both_sexes.tsv",
    snpid="variant",
    ea="minor_allele",
    eaf="minor_AF",
    beta="beta",
    se="se",
    p="pval",
    n="n_complete_samples",
    other=["low_confidence_variant", "AC", "ytx"]
)
# Out:
# 2026/03/07 08:11:26 GWASLab v4.0.4 https://cloufield.github.io/gwaslab/
# 2026/03/07 08:11:26 (C) 2022-2026, Yunye He, Kamatani Lab, GPL-3.0 license, gwaslab@gmail.com
# 2026/03/07 08:11:26 Python version: 3.12.3 (main, Jan 22 2026, 20:57:42) [GCC 13.3.0]
# 2026/03/07 08:11:26 Start to initialize gl.Sumstats from file :/mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser/Data/21001_raw.gwas.imputed_v3.both_sexes.tsv
# 2026/03/07 08:11:40  -Reading columns          : ytx,low_confidence_variant,n_complete_samples,minor_allele,variant,pval,se,AC,minor_AF,beta
# 2026/03/07 08:11:40  -Renaming columns to      : ytx,low_confidence_variant,N,EA,SNPID,P,SE,AC,EAF,BETA
# 2026/03/07 08:11:40  -Current Dataframe shape : 13791467  x  10
# 2026/03/07 08:11:40  -Initiating a status column: STATUS ...
# 2026/03/07 08:11:40 #WARNING! Version of genomic coordinates is unknown for homo sapiens (build: 99)...
# 2026/03/07 08:11:41 Start to reorder the columns ...(v4.0.4)
# 2026/03/07 08:11:41  -Reordering columns to    : SNPID,EA,STATUS,EAF,BETA,SE,P,N,low_confidence_variant,AC,ytx
# 2026/03/07 08:11:41 Finished reordering the columns.
# 2026/03/07 08:11:41  -Column  : SNPID  EA       STATUS EAF     BETA    SE      P       N     low_confidence_variant AC      ytx
# 2026/03/07 08:11:41  -DType   : object category int64  float64 float64 float64 float64 int64 bool                   float64 float64
# 2026/03/07 08:11:41  -Verified: T      T        T      T       T       T       T       T     NA                     NA      NA
# 2026/03/07 08:11:41  -Current Dataframe memory usage: 1014.01 MB
# 2026/03/07 08:11:42 Finished loading data successfully!

# %%
mysumstats.data
# Out:
#                       SNPID EA   STATUS           EAF        BETA  \
# 0               1:15791:C:T  T  9999999  5.446880e-09  894.616000
# 1               1:69487:G:A  A  9999999  5.768250e-06   -2.715450
# 2               1:69569:T:C  C  9999999  1.878960e-04   -0.484284
# 3              1:139853:C:T  T  9999999  5.681100e-06   -2.703560
# 4             1:692794:CA:C  C  9999999  1.105900e-01   -0.016436
# ...                     ... ..      ...           ...         ...
# 13791462    X:154929412:C:T  T  9999999  2.454730e-01   -0.016260
# 13791463   X:154929637:CT:C  C  9999999  2.297260e-01   -0.027098
# 13791464  X:154929952:CAA:C  C  9999999  2.394300e-01   -0.020494
# 13791465    X:154930230:A:G  G  9999999  2.458870e-01   -0.016347
# 13791466    X:154930487:T:A  A  9999999  1.955900e-02    0.007107
#
#                    SE         P       N  low_confidence_variant  \
# 0         1204.870000  0.457786  359983                    True
# 1            2.360060  0.249902  359983                    True
# 2            0.423462  0.252778  359983                    True
# 3            2.360130  0.251997  359983                    True
# 4            0.019585  0.401342  359983                   False
# ...               ...       ...     ...                     ...
# 13791462     0.010723  0.129427  359983                   False
# 13791463     0.011190  0.015456  359983                   False
# 13791464     0.011278  0.069202  359983                   False
# 13791465     0.010721  0.127334  359983                   False
# 13791466     0.036783  0.846790  359983                   False
#
#                      AC           ytx
# 0              0.003922  1.238950e-01
# 1              4.152940  1.035150e+02
# 2            135.278000  3.644560e+03
# 3              4.090200  1.018400e+02
# 4          79621.100000  2.179000e+06
# ...                 ...           ...
# 13791462  176732.000000  4.837480e+06
# 13791463  165395.000000  4.525550e+06
# 13791464  172381.000000  4.717910e+06
# 13791465  177030.000000  4.845680e+06
# 13791466   14081.800000  3.857390e+05
#
# [13791467 rows x 11 columns]
