# %% [markdown]
# Import Libraries and Define Paths

# %%
# Import necessary Python libraries
import os
import pandas as pd

# ----------------- Configuration Paths -----------------
# Base directory of the GWAS harmonizer project
BASE_DIR = "/mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser"

# Input GWAS summary statistics file
SUMSTATS = "/mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser/Data/21001_raw.gwas.imputed_v3.both_sexes.tsv.bgz"

# Reference genome build
BUILD = "GRCh37"

# Directory containing reference GWAS data for harmonization
REF_DIR = "/mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser/Data/gwas-ref"

# Path to the code repository (used for scripts and workflows)
CODE_REPO = BASE_DIR

# Allele frequency matching threshold for harmonization
THRESHOLD = "0.99"

# ----------------- Export as Environment Variables -----------------
# These variables will be accessible by Bash scripts and Nextflow
os.environ["SUMSTATS"] = SUMSTATS
os.environ["BUILD"] = BUILD
os.environ["REF_DIR"] = REF_DIR
os.environ["CODE_REPO"] = CODE_REPO
os.environ["THRESHOLD"] = THRESHOLD

# Print confirmation
print("Parameters exported:")
for key in ["SUMSTATS", "BUILD", "REF_DIR", "CODE_REPO", "THRESHOLD"]:
    print(f"{key} = {os.environ[key]}")
# Out:
# Parameters exported:
# SUMSTATS = /mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser/Data/21001_raw.gwas.imputed_v3.both_sexes.tsv.bgz
# BUILD = GRCh37
# REF_DIR = /mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser/Data/gwas-ref
# CODE_REPO = /mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser
# THRESHOLD = 0.99

# %%
# ---- paths based on your ls output ----
BASE_DIR = "/mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser"

SUMSTATS = "/mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser/Data/21001_raw.gwas.imputed_v3.both_sexes.tsv.bgz"
BUILD = "GRCh37"
REF_DIR = "/mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser/Data/gwas-ref"
CODE_REPO = BASE_DIR
THRESHOLD = "0.99"

# ---- export for bash / nextflow ----
os.environ["SUMSTATS"] = SUMSTATS
os.environ["BUILD"] = BUILD
os.environ["REF_DIR"] = REF_DIR
os.environ["CODE_REPO"] = CODE_REPO
os.environ["THRESHOLD"] = THRESHOLD

print("Parameters exported:")
for k in ["SUMSTATS", "BUILD", "REF_DIR", "CODE_REPO", "THRESHOLD"]:
    print(f"{k}={os.environ[k]}")
# Out:
# Parameters exported:
# SUMSTATS=/mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser/Data/21001_raw.gwas.imputed_v3.both_sexes.tsv.bgz
# BUILD=GRCh37
# REF_DIR=/mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser/Data/gwas-ref
# CODE_REPO=/mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser
# THRESHOLD=0.99

# %%
# %%bash
# set -e
#
# echo "Working directory:"
# pwd
# echo
#
# echo "Nextflow:"
# nextflow -version
# echo
#
# echo "bgzip / tabix:"
# which bgzip
# which tabix
# Out:
# Working directory:
# /mnt/hdd_1/ofgeha/galaxy-gwas-tools/Gwaslab
#
# Nextflow:
#
#       N E X T F L O W
#       version 25.10.0 build 10289
#       created 22-10-2025 16:26 UTC
#       cite doi:10.1038/nbt.3820
#       http://nextflow.io
#
#
# bgzip / tabix:
# /usr/bin/bgzip
# /usr/bin/tabix

# %%
# %%bash
# set -e
#
# cd "$CODE_REPO"
#
# echo "Repo contents:"
# ls
# Out:
# Repo contents:
# bin
# config
# Data
# Dockerfile
# environments
# example_wrapper.sh
# gwas-ref
# harmonization.ipynb
# harmonizer.notebook.log
# harmonizer_setup.sh
# harmonizer.sh
# htslib-1.21.tar.bz2
# logs
# main.nf
# modules
# nextflow
# nextflow.config
# nextflow_workflow.ipynb
# README.md
# ref-data
# subworkflows
# {{SUMSTATS}}.tsv
# test_data
# venv-py311
# work
# workflows

# %%
# %%bash
# set -euo pipefail
#
# echo "Running harmonizer with:"
# echo "  SUMSTATS   = $SUMSTATS"
# echo "  BUILD      = $BUILD"
# echo "  REF_DIR    = $REF_DIR"
# echo "  CODE_REPO  = $CODE_REPO"
# echo "  THRESHOLD  = $THRESHOLD"
# echo
#
# cd "$CODE_REPO"
#
# ./harmonizer.sh \
#   --input "$SUMSTATS" \
#   --build "$BUILD" \
#   --ref "$REF_DIR" \
#   --threshold "$THRESHOLD" \
#   --code-repo "$CODE_REPO"
# Out:
# Running harmonizer with:
#   SUMSTATS   = /mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser/Data/21001_raw.gwas.imputed_v3.both_sexes.tsv.bgz
#   BUILD      = GRCh37
#   REF_DIR    = /mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser/Data/gwas-ref
#   CODE_REPO  = /mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser
#   THRESHOLD  = 0.99
#
# ==== VALIDATE INPUT SUMSTATS ====
# === Converting GWAS SUMSTATS to SSF Format (this will also remove X, Y, MT chrs if they are in the data) ====

# %%
df = pd.read_csv("/mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser/Data/21001_raw/final/21001_raw.h.tsv.gz")

# %%
df.shape
# Out:
# (2246535, 1)
