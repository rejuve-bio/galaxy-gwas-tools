# %%
import gwaslab as gl
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import gwaslab as gl
#
# File /mnt/hdd_1/ofgeha/galaxytool/.venv/lib/python3.10/site-packages/gwaslab/__init__.py:4
#       1 from typing import TYPE_CHECKING, Optional, Dict, Any, Union
#       2 import pandas as pd
# ----> 4 from gwaslab.g_Sumstats import Sumstats
#       5 from gwaslab.g_Sumstats_polars import Sumstatsp
#       6 from gwaslab.g_SumstatsT import SumstatsT
#
# File /mnt/hdd_1/ofgeha/galaxytool/.venv/lib/python3.10/site-packages/gwaslab/g_Sumstats.py:16
#      14 from gwaslab.info.g_Sumstats_summary import lookupstatus, summarize
#      15 from gwaslab.info.g_version import _show_version, gwaslab_info
# ---> 16 from gwaslab.info.g_meta import (
#      17     _append_meta_record,
#      18     _check_sumstats_qc_status,
#      19     _init_meta,
#      20     _set_harmonization_status,
# ...
