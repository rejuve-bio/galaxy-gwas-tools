# %%
import gwaslab as gl
import pandas as pd
gl.show_version()
# Out:
# 2026/01/11 13:28:03 GWASLab v4.0.4 https://cloufield.github.io/gwaslab/
# 2026/01/11 13:28:03 (C) 2022-2026, Yunye He, Kamatani Lab, GPL-3.0 license, gwaslab@gmail.com
# 2026/01/11 13:28:03 Python version: 3.12.3 (main, Nov  6 2025, 13:44:16) [GCC 13.3.0]

# %%
# Load the dataset without mapping ea and eaf to minor
mysumstats = gl.Sumstats(
    "/mnt/hdd_1/ofgeha/galaxy-gwas-tools/Data/21001_raw.gwas.imputed_v3.both_sexes.tsv.bgz",
    snpid="variant",           
    beta="beta",
    se="se",
    p="pval",
    n="n_complete_samples",
    other=["low_confidence_variant", "AC"],
    verbose=True,
    readargs={
        "compression": "gzip",
        "sep": "\t"
    },
    fmt = "plink2"
)
# Out:
# 2026/01/11 13:28:03 GWASLab v4.0.4 https://cloufield.github.io/gwaslab/
# 2026/01/11 13:28:03 (C) 2022-2026, Yunye He, Kamatani Lab, GPL-3.0 license, gwaslab@gmail.com
# 2026/01/11 13:28:03 Python version: 3.12.3 (main, Nov  6 2025, 13:44:16) [GCC 13.3.0]
# 2026/01/11 13:28:03 Start to load format from formatbook....
# 2026/01/11 13:28:03  -plink2 format meta info:
# 2026/01/11 13:28:03   - format_name  : PLINK2 .glm.firth, .glm.logistic,.glm.linear
# 2026/01/11 13:28:03   - format_source  : https://www.cog-genomics.org/plink/2.0/formats
# 2026/01/11 13:28:03   - format_version  : Alpha 3.3 final (3 Jun)
# 2026/01/11 13:28:03   - last_check_date  :  20220806
# 2026/01/11 13:28:03  -plink2 to gwaslab format dictionary:
# 2026/01/11 13:28:03   - plink2 keys: ID,#CHROM,POS,REF,ALT,A1,OBS_CT,A1_FREQ,BETA,LOG(OR)_SE,SE,T_STAT,Z_STAT,P,LOG10_P,MACH_R2,OR
# 2026/01/11 13:28:03   - gwaslab values: SNPID,CHR,POS,REF,ALT,EA,N,EAF,BETA,SE,SE,T,Z,P,MLOG10P,INFO,OR
# 2026/01/11 13:28:03 Start to initialize gl.Sumstats from file :/mnt/hdd_1/ofgeha/galaxy-gwas-tools/Data/21001_raw.gwas.imputed_v3.both_sexes.tsv.bgz
# 2026/01/11 13:28:33  -Reading columns          : low_confidence_variant,beta,pval,variant,se,n_complete_samples,AC
# 2026/01/11 13:28:33  -Renaming columns to      : low_confidence_variant,BETA,P,SNPID,SE,N,AC
# 2026/01/11 13:28:33  -Current Dataframe shape : 13791467  x  7
# 2026/01/11 13:28:34  -Initiating a status column: STATUS ...
# 2026/01/11 13:28:34 #WARNING! Version of genomic coordinates is unknown for homo sapiens (build: 99)...
# 2026/01/11 13:28:34 Start to reorder the columns ...(v4.0.4)
# 2026/01/11 13:28:34  -Reordering columns to    : SNPID,STATUS,BETA,SE,P,N,low_confidence_variant,AC
# 2026/01/11 13:28:34 Finished reordering the columns.
# 2026/01/11 13:28:34  -Column  : SNPID  STATUS BETA    SE      P       N     low_confidence_variant AC
# 2026/01/11 13:28:34  -DType   : object int64  float64 float64 float64 int64 bool                   float64
# 2026/01/11 13:28:34  -Verified: T      T      T       T       T       T     NA                     NA
# 2026/01/11 13:28:34  -Current Dataframe memory usage: 749.70 MB
# 2026/01/11 13:28:34 Finished loading data successfully!

# %%
mysumstats.data
# Out:
#                       SNPID   STATUS        BETA           SE         P  \
# 0               1:15791:C:T  9999999  894.616000  1204.870000  0.457786
# 1               1:69487:G:A  9999999   -2.715450     2.360060  0.249902
# 2               1:69569:T:C  9999999   -0.484284     0.423462  0.252778
# 3              1:139853:C:T  9999999   -2.703560     2.360130  0.251997
# 4             1:692794:CA:C  9999999   -0.016436     0.019585  0.401342
# ...                     ...      ...         ...          ...       ...
# 13791462    X:154929412:C:T  9999999   -0.016260     0.010723  0.129427
# 13791463   X:154929637:CT:C  9999999   -0.027098     0.011190  0.015456
# 13791464  X:154929952:CAA:C  9999999   -0.020494     0.011278  0.069202
# 13791465    X:154930230:A:G  9999999   -0.016347     0.010721  0.127334
# 13791466    X:154930487:T:A  9999999    0.007107     0.036783  0.846790
#
#                N  low_confidence_variant             AC
# 0         359983                    True       0.003922
# 1         359983                    True       4.152940
# 2         359983                    True     135.278000
# 3         359983                    True       4.090200
# 4         359983                   False   79621.100000
# ...          ...                     ...            ...
# 13791462  359983                   False  176732.000000
# 13791463  359983                   False  165395.000000
# 13791464  359983                   False  172381.000000
# 13791465  359983                   False  177030.000000
# 13791466  359983                   False   14081.800000
#
# [13791467 rows x 8 columns]

# %%
mysumstats.liftover(from_build="19", to_build="38")
# Out:
# 2026/01/11 13:30:16 Start to perform liftover ...(v4.0.4)
# 2026/01/11 13:30:16  -Current Dataframe shape : 13791467 x 8 ; Memory usage: 749.70 MB
# 2026/01/11 13:30:16 #WARNING! Necessary columns for .liftover() were not detected:CHR,POS
