# %%
import gwaslab as gl

# %%
import pandas as pd
import gwaslab as gl

# Load gzipped GWAS summary stats
df = pd.read_csv(
    "/mnt/hdd_1/ofgeha/galaxytool/Data/21001_raw.gwas.imputed_v3.both_sexes.tsv.bgz",
    sep="\t",
    compression="gzip"
)

# Split variant into CHR, POS, REF, ALT
df[['CHR', 'POS', 'REF', 'ALT']] = df['variant'].str.split(":", expand=True)
df['POS'] = df['POS'].astype(int)

# %%
# Create GWASLab Sumstats object and run liftover in one go
my_sumstats = (
    gl.Sumstats(
        df,
        snpid="variant",
        chrom="CHR",
        pos="POS",
        ea="minor_allele",
        beta="beta",
        se="se",
        p="pval",
        n="n_complete_samples",
        maf="minor_AF",
        verbose=True
    )
    .fix_chr()                    # fixes any CHR dtype issues automatically
    .liftover(from_build="19", to_build="38")  # liftover to hg38
)
# Out:
# 2026/01/02 23:54:06 GWASLab v4.0.2 https://cloufield.github.io/gwaslab/
# 2026/01/02 23:54:06 (C) 2022-2026, Yunye He, Kamatani Lab, GPL-3.0 license, gwaslab@gmail.com
# 2026/01/02 23:54:06 Python version: 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# 2026/01/02 23:54:06 Start to initialize gl.Sumstats from pandas DataFrame ...
# 2026/01/02 23:54:20  -Reading columns          : CHR,beta,n_complete_samples,minor_AF,se,pval,variant,minor_allele,POS
# 2026/01/02 23:54:20  -Renaming columns to      : CHR,BETA,N,MAF,SE,P,SNPID,EA,POS
# 2026/01/02 23:54:20  -Current Dataframe shape : 13791467  x  15
# 2026/01/02 23:54:28  -Initiating a status column: STATUS ...
# 2026/01/02 23:54:28 #WARNING! Version of genomic coordinates is unknown for homo sapiens (build: 99)...
# 2026/01/02 23:54:29  NEA not available: assigning REF to NEA...
# 2026/01/02 23:54:29  -EA,REF and ALT columns are available: assigning NEA...
# 2026/01/02 23:54:31  -For variants with EA == ALT : assigning REF to NEA ...
# 2026/01/02 23:54:35  -For variants with EA != ALT : assigning ALT to NEA ...
# 2026/01/02 23:54:42 Start to reorder the columns ...(v4.0.2)
# 2026/01/02 23:54:42  -Reordering columns to    : SNPID,CHR,POS,EA,NEA,STATUS,REF,ALT,MAF,BETA,SE,P,N,low_confidence_variant,AC,ytx,tstat
# 2026/01/02 23:54:50 Finished reordering the columns.
# 2026/01/02 23:54:51  -Trying to convert datatype for CHR: string -> Int64...Failed...
# 2026/01/02 23:54:53  -Column  : SNPID  CHR    POS   EA       NEA      STATUS REF      ALT      MAF     BETA    SE      P       N     low_confidence_variant AC      ytx     tstat
# 2026/01/02 23:54:53  -DType   : object string int64 category category int64  category category float64 float64 float64 float64 int64 bool                   float64 float64 float64
# 2026/01/02 23:54:53  -Verified: T      F      T     T        T        T      T        T        T       T       T       T       T     NA                     NA      NA      NA
# 2026/01/02 23:54:53 #WARNING! Columns with possibly incompatible dtypes: CHR
# 2026/01/02 23:54:53 #WARNING! Consider using Sumstats.fix_chr() to fix CHR dtype
# 2026/01/02 23:54:53  -Current Dataframe memory usage: 1493.68 MB
# 2026/01/02 23:54:54 Finished loading data successfully!
# 2026/01/02 23:54:54 Start to fix chromosome notation (CHR) ...(v4.0.2)
# 2026/01/02 23:54:54  -Current Dataframe shape : 13791467 x 17 ; Memory usage: 1493.68 MB
# 2026/01/02 23:54:54  -Checking CHR data type...
# 2026/01/02 23:54:55  -Variants with standardized chromosome notation: 13364303
# 2026/01/02 23:54:56  -Variants with fixable chromosome notations: 427164
# 2026/01/02 23:54:56  -No unrecognized chromosome notations...
# 2026/01/02 23:54:56  -Identifying non-autosomal chromosomes : X, Y, and MT ...
# 2026/01/02 23:54:56  -Identified 427164 variants on sex chromosomes...
# 2026/01/02 23:54:56  -Standardizing first sex chromosome chromosome notations: X to 23...
# 2026/01/02 23:55:09 Finished fixing chromosome notation (CHR).
# 2026/01/02 23:55:09 Start to perform liftover ...(v4.0.2)
# 2026/01/02 23:55:09  -Using built-in chain file: /mnt/hdd_1/ofgeha/galaxytool/py312/lib/python3.12/site-packages/gwaslab/data/chains/hg19ToHg38.over.chain.gz
# 2026/01/02 23:55:11  -No variants with status code xxx0xxx to liftover
# 2026/01/02 23:55:11 Finished liftover.

# %%
my_sumstats.data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 my_sumstats.data
#
# AttributeError: 'NoneType' object has no attribute 'data'
