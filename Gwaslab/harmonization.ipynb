# %%
# Examples:
# chroms = [22]                    # quick test
# chroms = list(range(1, 23))      # autosomes
chroms = list(range(1, 24))      # 1–23
# chroms = None                    # FULL genome

# chroms = None   # <-- global run

# %%
import gzip

def filter_gwas_by_chrom(
    input_gwas,
    output_gwas,
    chroms=None,
    chrom_col=0
):
    """
    chroms: list[int] or None
    chrom_col: 0-based column index of chromosome
    """

    if chroms is None:
        # No filtering → copy file as-is
        with gzip.open(input_gwas, "rb") as fin, gzip.open(output_gwas, "wb") as fout:
            fout.write(fin.read())
        return "unfiltered"

    chroms = set(str(c) for c in chroms)

    with gzip.open(input_gwas, "rt") as fin, gzip.open(output_gwas, "wt") as fout:
        header = fin.readline()
        fout.write(header)

        for line in fin:
            if line.split("\t")[chrom_col] in chroms:
                fout.write(line)

    return f"filtered_chr_{'_'.join(sorted(chroms))}"

# %%
input_gwas = "/mnt/hdd_1/ofgeha/test/21001_raw.gwas.imputed_v3.both_sexes.tsv.gz"

if chroms is None:
    gwas_for_nf = input_gwas
    mode = "global"
else:
    gwas_for_nf = "/mnt/hdd_1/ofgeha/test/21001_raw_subset.tsv.gz"
    mode = filter_gwas_by_chrom(
        input_gwas,
        gwas_for_nf,
        chroms=chroms
    )

print("Run mode:", mode)
print("GWAS used:", gwas_for_nf)

# %%
import subprocess

cmd = [
    "nextflow", "run", "EBISPOT/gwas-sumstats-harmoniser",
    "-r", "v1.1.10",
    "--ref", "/mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser/gwas-ref",
    "--harm",
    "--file", input_gwas,
    "--chromlist", "22,",
    "--terminate_error", "ignore",
    "-profile", "standard,singularity",
    # "-resume"
]


print(" ".join(cmd))
subprocess.run(cmd, check=True)
# Out:
# nextflow run EBISPOT/gwas-sumstats-harmoniser -r v1.1.10 --ref /mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser/gwas-ref --harm --file /mnt/hdd_1/ofgeha/test/21001_raw.gwas.imputed_v3.both_sexes.tsv.gz --chromlist 22, --terminate_error ignore -profile standard,singularity
# Nextflow 25.10.3 is available - Please consider updating your version to it
#  N E X T F L O W   ~  version 25.10.0
#
# Launching `https://github.com/EBISPOT/gwas-sumstats-harmoniser` [sharp_nobel] DSL2 - revision: 436c17a91c [v1.1.10]
#
# Start harmonising files
# Harmonizing the file /mnt/hdd_1/ofgeha/test/21001_raw.gwas.imputed_v3.both_sexes.tsv.gz
# [-        ] NFC…jor_direction:map_to_build -
# [-        ] NFC…rection:ten_percent_counts -
# [-        ] NFC…ion:ten_percent_counts_sum -
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [-        ] NFC…RM:main_harm:harmonization -
# [-        ] NFC…arm:concatenate_chr_splits -
# [-        ] NFC…LOGHARM:quality_control:qc -
# [-        ] NFC…_control:harmonization_log -
# [-        ] NFC…y_control:update_meta_yaml -
# no,other setting
# [chr22,  is being harmonized]
#
# executor >  local (1)
# [1b/d341fe] NFC…n:map_to_build (21001_raw) | 0 of 1
# [-        ] NFC…rection:ten_percent_counts -
# [-        ] NFC…ion:ten_percent_counts_sum -
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [-        ] NFC…RM:main_harm:harmonization -
# [-        ] NFC…arm:concatenate_chr_splits -
# [-        ] NFC…LOGHARM:quality_control:qc -
# [-        ] NFC…_control:harmonization_log -
# [-        ] NFC…y_control:update_meta_yaml -
# no,other setting
# [chr22,  is being harmonized]
#
# executor >  local (1)
# [1b/d341fe] NFC…n:map_to_build (21001_raw) | 0 of 1
# [-        ] NFC…rection:ten_percent_counts -
# [-        ] NFC…ion:ten_percent_counts_sum -
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [-        ] NFC…RM:main_harm:harmonization -
# [-        ] NFC…arm:concatenate_chr_splits -
# [-        ] NFC…LOGHARM:quality_control:qc -
# [-        ] NFC…_control:harmonization_log -
# [-        ] NFC…y_control:update_meta_yaml -
# no,other setting
# [chr22,  is being harmonized]
#
# executor >  local (2)
# [1b/d341fe] NFC…n:map_to_build (21001_raw) | 1 of 1 ✔
# [c8/42959b] NFC…t_counts (21001_raw_chr22) | 0 of 1
# [-        ] NFC…ion:ten_percent_counts_sum -
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [-        ] NFC…RM:main_harm:harmonization -
# [-        ] NFC…arm:concatenate_chr_splits -
# [-        ] NFC…LOGHARM:quality_control:qc -
# [-        ] NFC…_control:harmonization_log -
# [-        ] NFC…y_control:update_meta_yaml -
#
#
#
# executor >  local (2)
# [1b/d341fe] NFC…n:map_to_build (21001_raw) | 1 of 1 ✔
# [c8/42959b] NFC…t_counts (21001_raw_chr22) | 0 of 1
# [-        ] NFC…ion:ten_percent_counts_sum -
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [-        ] NFC…RM:main_harm:harmonization -
# [-        ] NFC…arm:concatenate_chr_splits -
# [-        ] NFC…LOGHARM:quality_control:qc -
# [-        ] NFC…_control:harmonization_log -
# [-        ] NFC…y_control:update_meta_yaml -
#
#
#
# executor >  local (3)
# [1b/d341fe] NFC…n:map_to_build (21001_raw) | 1 of 1 ✔
# [c8/42959b] NFC…t_counts (21001_raw_chr22) | 1 of 1 ✔
# [be/31fbb4] NFC…ent_counts_sum (21001_raw) | 0 of 1
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [-        ] NFC…RM:main_harm:harmonization -
# [-        ] NFC…arm:concatenate_chr_splits -
# [-        ] NFC…LOGHARM:quality_control:qc -
# [-        ] NFC…_control:harmonization_log -
# [-        ] NFC…y_control:update_meta_yaml -
#
# executor >  local (4)
# [1b/d341fe] NFC…n:map_to_build (21001_raw) | 1 of 1 ✔
# [c8/42959b] NFC…t_counts (21001_raw_chr22) | 1 of 1 ✔
# [be/31fbb4] NFC…ent_counts_sum (21001_raw) | 1 of 1 ✔
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [e4/fc868e] NFC…nization (21001_raw_chr22) | 0 of 1
# [-        ] NFC…arm:concatenate_chr_splits -
# [-        ] NFC…LOGHARM:quality_control:qc -
# [-        ] NFC…_control:harmonization_log -
# [-        ] NFC…y_control:update_meta_yaml -
#
# executor >  local (5)
# [1b/d341fe] NFC…n:map_to_build (21001_raw) | 1 of 1 ✔
# [c8/42959b] NFC…t_counts (21001_raw_chr22) | 1 of 1 ✔
# [be/31fbb4] NFC…ent_counts_sum (21001_raw) | 1 of 1 ✔
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [e4/fc868e] NFC…nization (21001_raw_chr22) | 1 of 1 ✔
# [eb/d40ab1] NFC…ate_chr_splits (21001_raw) | 0 of 1
# [-        ] NFC…LOGHARM:quality_control:qc -
# [-        ] NFC…_control:harmonization_log -
# [-        ] NFC…y_control:update_meta_yaml -
#
# executor >  local (5)
# [1b/d341fe] NFC…n:map_to_build (21001_raw) | 1 of 1 ✔
# [c8/42959b] NFC…t_counts (21001_raw_chr22) | 1 of 1 ✔
# [be/31fbb4] NFC…ent_counts_sum (21001_raw) | 1 of 1 ✔
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [e4/fc868e] NFC…nization (21001_raw_chr22) | 1 of 1 ✔
# [eb/d40ab1] NFC…ate_chr_splits (21001_raw) | 0 of 1
# [-        ] NFC…LOGHARM:quality_control:qc -
# [-        ] NFC…_control:harmonization_log -
# [-        ] NFC…y_control:update_meta_yaml -
#
# executor >  local (6)
# [1b/d341fe] NFC…n:map_to_build (21001_raw) | 1 of 1 ✔
# [c8/42959b] NFC…t_counts (21001_raw_chr22) | 1 of 1 ✔
# [be/31fbb4] NFC…ent_counts_sum (21001_raw) | 1 of 1 ✔
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [e4/fc868e] NFC…nization (21001_raw_chr22) | 1 of 1 ✔
# [eb/d40ab1] NFC…ate_chr_splits (21001_raw) | 1 of 1 ✔
# [f5/fdbb8b] NFC…ity_control:qc (21001_raw) | 0 of 1
# [-        ] NFC…_control:harmonization_log -
# [-        ] NFC…y_control:update_meta_yaml -
#
# executor >  local (6)
# [1b/d341fe] NFC…n:map_to_build (21001_raw) | 1 of 1 ✔
# [c8/42959b] NFC…t_counts (21001_raw_chr22) | 1 of 1 ✔
# [be/31fbb4] NFC…ent_counts_sum (21001_raw) | 1 of 1 ✔
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [e4/fc868e] NFC…nization (21001_raw_chr22) | 1 of 1 ✔
# [eb/d40ab1] NFC…ate_chr_splits (21001_raw) | 1 of 1 ✔
# [f5/fdbb8b] NFC…ity_control:qc (21001_raw) | 1 of 1 ✔
# [-        ] NFC…_control:harmonization_log -
# [-        ] NFC…y_control:update_meta_yaml -
#
# executor >  local (7)
# [1b/d341fe] NFC…n:map_to_build (21001_raw) | 1 of 1 ✔
# [c8/42959b] NFC…t_counts (21001_raw_chr22) | 1 of 1 ✔
# [be/31fbb4] NFC…ent_counts_sum (21001_raw) | 1 of 1 ✔
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [e4/fc868e] NFC…nization (21001_raw_chr22) | 1 of 1 ✔
# [eb/d40ab1] NFC…ate_chr_splits (21001_raw) | 1 of 1 ✔
# [f5/fdbb8b] NFC…ity_control:qc (21001_raw) | 1 of 1 ✔
# [4a/14655e] NFC…monization_log (21001_raw) | 0 of 1
# [-        ] NFC…y_control:update_meta_yaml -
#
# executor >  local (8)
# [1b/d341fe] NFC…n:map_to_build (21001_raw) | 1 of 1 ✔
# [c8/42959b] NFC…t_counts (21001_raw_chr22) | 1 of 1 ✔
# [be/31fbb4] NFC…ent_counts_sum (21001_raw) | 1 of 1 ✔
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [e4/fc868e] NFC…nization (21001_raw_chr22) | 1 of 1 ✔
# [eb/d40ab1] NFC…ate_chr_splits (21001_raw) | 1 of 1 ✔
# [f5/fdbb8b] NFC…ity_control:qc (21001_raw) | 1 of 1 ✔
# [4a/14655e] NFC…monization_log (21001_raw) | 1 of 1 ✔
# [ba/157c5c] NFC…date_meta_yaml (21001_raw) | 0 of 1
#
# executor >  local (8)
# [1b/d341fe] NFC…n:map_to_build (21001_raw) | 1 of 1 ✔
# [c8/42959b] NFC…t_counts (21001_raw_chr22) | 1 of 1 ✔
# [be/31fbb4] NFC…ent_counts_sum (21001_raw) | 1 of 1 ✔
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [e4/fc868e] NFC…nization (21001_raw_chr22) | 1 of 1 ✔
# [eb/d40ab1] NFC…ate_chr_splits (21001_raw) | 1 of 1 ✔
# [f5/fdbb8b] NFC…ity_control:qc (21001_raw) | 1 of 1 ✔
# [4a/14655e] NFC…monization_log (21001_raw) | 1 of 1 ✔
# [ba/157c5c] NFC…date_meta_yaml (21001_raw) | 1 of 1 ✔
#
# executor >  local (8)
# [1b/d341fe] NFC…n:map_to_build (21001_raw) | 1 of 1 ✔
# [c8/42959b] NFC…t_counts (21001_raw_chr22) | 1 of 1 ✔
# [be/31fbb4] NFC…ent_counts_sum (21001_raw) | 1 of 1 ✔
# [-        ] NFC…ion:generate_strand_counts -
# [-        ] NFC…on:summarise_strand_counts -
# [e4/fc868e] NFC…nization (21001_raw_chr22) | 1 of 1 ✔
# [eb/d40ab1] NFC…ate_chr_splits (21001_raw) | 1 of 1 ✔
# [f5/fdbb8b] NFC…ity_control:qc (21001_raw) | 1 of 1 ✔
# [4a/14655e] NFC…monization_log (21001_raw) | 1 of 1 ✔
# [ba/157c5c] NFC…date_meta_yaml (21001_raw) | 1 of 1 ✔
# Completed at: 03-Feb-2026 05:30:29
# Duration    : 6m 3s
# CPU hours   : 0.1
# Succeeded   : 8
# CompletedProcess(args=['nextflow', 'run', 'EBISPOT/gwas-sumstats-harmoniser', '-r', 'v1.1.10', '--ref', '/mnt/hdd_1/ofgeha/gwas-sumstats-harmoniser/gwas-ref', '--harm', '--file', '/mnt/hdd_1/ofgeha/test/21001_raw.gwas.imputed_v3.both_sexes.tsv.gz', '--chromlist', '22,', '--terminate_error', 'ignore', '-profile', 'standard,singularity'], returncode=0)

# %%
import pandas as pd
df = pd.read_csv("/mnt/hdd_1/ofgeha/galaxy-gwas-tools/Gwaslab/21001_raw/final/21001_raw.h.tsv.gz")

# %%
df.shape
# Out:
# (141200, 1)
