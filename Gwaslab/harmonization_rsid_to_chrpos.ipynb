# %%
import sys
sys.path.insert(0,"/home/yunye/work/gwaslab/src")
import gwaslab as gl
import pandas as pd

# %% [markdown]
# ### loading

# %%
gl.check_downloaded_ref()
# Out:
# 2026/01/10 13:31:45 Start to check downloaded reference files...
# 2026/01/10 13:31:45  -Checking the config file:/mnt/hdd_1/ofgeha/galaxy-gwas-tools/.venv/lib/python3.12/site-packages/gwaslab/data/config.json
# 2026/01/10 13:31:45  -Config file exists.
# 2026/01/10 13:31:45  -Updating config.json...
# 2026/01/10 13:31:45  - Local file keywords:  1kg_dbsnp151_hg38_auto
# {'1kg_dbsnp151_hg38_auto': {'local_path': '/home/ofgeha/.gwaslab/1kg_dbsnp151_hg38_auto.txt.gz',
#   'description': '1KG dbSNP151 hg38 auto variants table containing SNP ID, chromosome, position, effect allele, non-effect allele, and rsID mappings for autosomal variants.',
#   'suggested_use': 'SNP annotation and rsID mapping'}}

# %%
mysumstats = gl.Sumstats(
    "/mnt/hdd_1/ofgeha/galaxy-gwas-tools/Data/21001_T2T_liftover.tsv.gz",
    snpid="SNPID",
    chrom="CHR",
    pos="POS",
    ea="EA",            
    nea="NEA",          
    eaf="EAF",          
    beta="BETA",
    se="SE",
    p="P",
    # Note: 'Dir' and 'N' are not in your column list, 
    # so we should omit them or point to the correct ones.
    # n="n_complete_samples", # Optional: if you want to use sample size
    verbose=True,
    readargs={'sep': '\t'}
)
# Out:
# 2026/01/10 13:40:56 GWASLab v4.0.4 https://cloufield.github.io/gwaslab/
# 2026/01/10 13:40:56 (C) 2022-2026, Yunye He, Kamatani Lab, GPL-3.0 license, gwaslab@gmail.com
# 2026/01/10 13:40:56 Python version: 3.12.3 (main, Nov  6 2025, 13:44:16) [GCC 13.3.0]
# 2026/01/10 13:40:56 Start to initialize gl.Sumstats from file :/mnt/hdd_1/ofgeha/galaxy-gwas-tools/Data/21001_T2T_liftover.tsv.gz
# 2026/01/10 13:41:26  -Reading columns          : SNPID,EAF,CHR,POS,EA,P,NEA,SE,BETA
# 2026/01/10 13:41:26  -Renaming columns to      : SNPID,EAF,CHR,POS,EA,P,NEA,SE,BETA
# 2026/01/10 13:41:26  -Current Dataframe shape : 13640038  x  9
# 2026/01/10 13:41:27  -Initiating a status column: STATUS ...
# 2026/01/10 13:41:27 #WARNING! Version of genomic coordinates is unknown for homo sapiens (build: 99)...
# 2026/01/10 13:41:30 Start to reorder the columns ...(v4.0.4)
# 2026/01/10 13:41:30  -Reordering columns to    : SNPID,CHR,POS,EA,NEA,STATUS,EAF,BETA,SE,P
# 2026/01/10 13:41:31 Finished reordering the columns.
# 2026/01/10 13:41:31  -Trying to convert datatype for CHR: string -> Int64...Success
# 2026/01/10 13:41:32  -Column  : SNPID  CHR   POS   EA       NEA      STATUS EAF     BETA    SE      P
# 2026/01/10 13:41:32  -DType   : object Int64 int64 category category int64  float64 float64 float64 float64
# 2026/01/10 13:41:32  -Verified: T      T     T     T        T        T      T       T       T       T
# 2026/01/10 13:41:33  -Current Dataframe memory usage: 953.30 MB
# 2026/01/10 13:41:33 Finished loading data successfully!
